# %% [markdown]
# <H1 style="color:navy;"><p style="font-family:Georgia;"><B><I><Center>Optimizing Data Packet Routing Paths for Airplanes over North Atlantic</Center></I></B></p></H1>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Submitted By: -</H3>
# <body><p style="font-family:Georgia;">Name of Student: - Tanmayee Vilas Salunke</p>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Abstract: -</H3>
# <body>
# <p style="font-family:Georgia;">This paper presents a novel approach for finding an optimal path between each airplane and a ground station in a North Atlantic region. First, a Greedy Algorithm, Genetic Search Algorithm and Particle Swarm Optimization algorithms are used to find the optimal path with two criteria, namely, maximum end-to-end data transmission rate and minimum end-to-end latency. Then, the results of the algorithms are compared and the best routing path is selected for each airplane. In addition, the performance of the proposed approach is evaluated based on the data collected from 216 airplanes flying over North Atlantic. The results show that the proposed approach can efficiently provide an optimal routing path to maximize the end-to-end data transmission rate and minimize end-to-end latency.</p>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Problem Statement: -</H3>
# <body>
# <p style="font-family:Georgia;">The given problem consists of data of 216 airplanes flying over North Atlantic. We are given two Ground Stations Heathrow (LHR) and Newark Liberty International Airport (EWR). In order to provide Internet access to passengers onboard, each airplane needs to find an optimal data packet routing path to a ground station (GS) in terms of one or two and more objectives to be optimized. For finding the optimum path between each airplane, Greedy Algorithm, Genetic Search Algorithm and Particle Swarm Optimization is implemented. Given a set of airplanes and a set of ground stations,
# <p style="font-family:Georgia;">1) Find a routing path for each airplane that can access any of the ground stations such that the end-to-end data transmission rate is maximized.</p>
# <p style="font-family:Georgia;">2) Find a routing path for each airplane that has the maximum end-to-end data transmission rate and the minimum end-to-end latency.</p>
# </body>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Literature Review: -</H3>
# <body>
# <p style="font-family:Georgia;">Aircraft mobility modelling is an important tool for understanding the behaviour of aeronautical networks. Semi-stochastic aircraft mobility modelling is a technique used to investigate the effects of random perturbations on aircraft and their flight paths. This review examines recent research into semi-stochastic aircraft mobility modelling for aeronautical networks, focusing on a case-study based on real flight data from Australia[1].</p>
# <p style="font-family:Georgia;">The ELD problem has been successfully solved using a variety of optimization techniques. For each algorithm, the best, worst, average fitness, and their standard deviation have been found. The findings indicate that a PSO approach provides the best operating cost. It has been noted that the fmincon approach produces consistent results with zero cost standard deviation. Additionally, it has been found that adopting a hybrid genetic algorithm can lower the variety of GA[3].</p>
# <p style="font-family:Georgia;">The suggested -DMOGA has been used in the research to jointly optimise the end-to-end SE, end-to-end latency, and the PET in order to identify the Pareto-optimal routing pathways. On two comparable dates in 2018, the busiest day of June 29 and the quietest day of December 25, in terms of the number of flights in the air, we studied the attainable end-to-end SE, end-to-end latency, and PET performance utilising our -DMOGA based multiple-objective routing optimization[4].</p>
# <p style="font-family:Georgia;"> Inspired by the papers I have read, I have chosen to use a greedy algorithm as the foundation for my solution, and then compare its results to those of genetic algorithms and particle swarm optimization.</p>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Dataset Description: -</H3>
# <p style="font-family:Georgia;">The given dataset contains the data of 216 flights flying over North Atlantic. There are five columns and 216 rows in the dataset. The columns in the dataset are: -</p>
# <ol style="font-family:Georgia;"><li>Flight Number: - Each flight is assigned unique flight number.</li>
# <li>Time Stamp: - A flight timestamp is the time at which a flight departs or arrives. In this dataset is UTC time 13:00 of Jun 29th, 2018.</li>
# <li>Altitude: - Vertical distance from the measurement location to mean sea level. Altitude in this dataset is given feet.</li>
# <li>Longitude: - Longitude is a geographic coordinate that specifies the east-west position of a point on the Earth's surface. It is an angular measurement, usually expressed in degrees, minutes, and seconds, and is traditionally measured from the Prime Meridian. Longitude is given in degree.</li>
# <li>Latitude : - Latitude is a geographic coordinate that specifies a location's distance north or south of the Earth's equatorial plane. Latitude is given in degree.</li></ol>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Two key metrics:- </H3>
# <body>
# <ol style="font-family:Georgia;"><li> The end-to-end latency of a routing path is the total delay experienced by data as it travels through the path from the source to the destination. It is determined by the sum of the delays imposed by each link in the path.</li>
# <li> The end-to-end data transmission rate is the minimum rate at which data can be transmitted through a given routing path, taking into account the data transmission rate of each link in the path. It is determined by the link with the lowest data transmission rate. Optimizing the end-to-end data transmission rate is important in networking, as it determines the maximum rate at which data can be transmitted through a given path. </li> </body>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Method to solve the given problems: - </H3>
# <p style="font-family:Georgia;">Dynamic routing: In dynamic routing, the router uses algorithms to calculate the best path for data packets. Dynamic routing is typically used in large networks.</p>
# <p style="font-family:Georgia;"><B>For single Objective Function</B>
# <ol style="font-family:Georgia;"><li>Find a routing path for each airplane that can access any of the ground stations such that the end-to-end data transmission rate is maximized.</li>
# <li> Sort the airplanes by their data transmission rates.</li>
# <li> Select the first airplane and find the shortest path to either LHR or EWR.</li>
# <li> Repeat step 2 for the remaining airplanes.</li>
# <li> Find the path with the maximum data transmission rate.</li></ol>
#
# <p style="font-family:Georgia;"><B>For Multiple Objective Function[4]</B></p>
# <ol style="font-family:Georgia;"><li> Calculate the distance between Heathrow Airport and Newark Liberty International Airport.</li>
# <li> Estimate the maximum end-to-end data transmission rate and minimum end-to-end latency for different paths from Heathrow Airport to Newark Liberty International Airport.</li>
# <li> Develop a multiple-objective optimization model to identify the optimal path that maximizes the end-to-end data transmission rate and minimizes the end-to-end latency.</li>
# <li> Use an appropriate optimization algorithm to solve the model.</li>
# <li> Analyze the results and select the optimal path having the maximum end-to-end data transmission rate and minimum end-to-end latency.</li>
# <li> Implement the selected path for each airplane that can access any of the GS.</li></ol>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Mathematical Equation End-to-End Latency</H3>
#
# <H3><center>$Latency = \sum\limits _{i=1} ^{l-1}  Delay(link[i][i+1])$</center></H3>
#
# <p style="font-family:Georgia;">Where "Σ" represents the sum of a series and "Delay(link<sub>i</sub>)" is the delay imposed by each individual link in the series, which is assumed to be 50 milliseconds (ms) for each link.

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Mathematical Equation for Data Transmission Rate</H3>
# <p style="font-family:Georgia;"><math mathml="r = min(r12, r23, ..., r(l-1)l)">
#   <H3><center style="font-family:Georgia;">r = min(r<sub>1,2</sub>, r<sub>2,3</sub>, ..., r<sub>(l-1),l</sub>)</H3>
# </math>
# <p style="font-family:Georgia;">l minimum length of path
# <p style="font-family:Georgia;">r datarate between two links

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Algorithms used: -</H3>
# <H5 style="color:green;"><p style="font-family:Georgia;"><B> 1) Greedy Algorithm</B></H5>
# <p style="font-family:Georgia;">A greedy algorithm is a type of algorithm that follows the problem-solving heuristic of making the locally optimal choice at each stage with the hope of finding a global optimum. In other words, a greedy algorithm makes the most optimal choice at each step, without worrying about the consequences of that choice on future steps.
# <p style="font-family:Georgia;"><B>Advantages of Greedy Algorithm: -</B></p>
# <ol style="font-family:Georgia;"><li>Greedy algorithms have a reasonable degree of time complexity and space complexity.</li>
# <li>Greedy algorithms often provide reasonably good solutions to optimization problems.</li>
# <li>Greedy algorithms can be used to solve problems that have multiple solutions.</li>
# <li>Greedy algorithms can be used to solve problems that have optimal solutions.</li></ol>
# <p style="font-family:Georgia;"><B> Reason to choose Greedy Algorithm for given problem: - </B></p>
# <p style="font-family:Georgia;">The Greedy Algorithm is a popular algorithm for solving optimisation problems due to its ability to quickly find a solution that is close to the optimal solution. The Greedy Algorithm works by making the best local decision at each step, rather than trying to look at the overall picture. This makes it particularly suitable for the given problem, as it can quickly evaluate the different paths to find the best one that satisfies the objectives. Additionally, the Greedy Algorithm is relatively simple to implement, making it a good choice for this problem.
#
# <H5 style="color:green;"><p style="font-family:Georgia;"><B> 2) Genetic Algorithm</B></H5>
# <p style="font-family:Georgia;">A genetic algorithm (GA) is a search algorithm and heuristic technique that is inspired by Charles Darwin's theory of natural selection. This technique is used in computational biology and bioinformatics to find optimal or near-optimal solutions to complex problems. The algorithm works by first creating a population of random solutions (called "chromosomes"). These solutions are then evaluated against a set of criteria (called "fitness function"). The fittest solutions are then selected to produce the next generation of solutions. This process is repeated until a desired goal is reached. The main advantages of using GA are its efficiency and flexibility. GA can be applied to a wide range of problems and it is relatively easy to implement. The main disadvantage of GA is that it can be slow to converge on a solution[2].</p>
# <p style="font-family:Georgia;"><B>Advantages of Genetic Algorithm: -</B></p>
# <ol style="font-family:Georgia;"><li>They are Resilient</li>
# <li>Optimisation across huge spatial state is provided</li>
# <li>They do not fail due to a little input change or the presence of noise, in contrast to classical AI</li></ol>
# <p style="font-family:Georgia;"><B>Reason to choose Genetic Algorithm for the given problem: -</B></p>
# <p style="font-family:Georgia;">The genetic algorithm is well suited for this problem because of its ability to explore a large search space and identify the optimal solution. The algorithm works by taking into account the various parameters of the aircraft, such as its altitude, and using a combination of selection, crossover, and mutation to explore the search space and find the best path with the highest data transmission rate. The algorithm is also highly efficient and can converge on a solution quickly, making it an ideal choice for this single-objective and multiple-objective optimization problem.</p>
#
# <H5 style="color:green;"><p style="font-family:Georgia;"><B> 3) Particle Swarm Optimization</B></P></H5>
# <p style="font-family:Georgia;">Particle Swarm Optimization (PSO) is a type of evolutionary algorithm used for optimization tasks. It is a population-based stochastic optimization technique, which is inspired by the social behavior of birds. PSO works by having a population of particles, each with its own position in search space, and the algorithm searches for optimal solutions by making the particles move in the search space according to certain rules. The algorithm uses two types of forces: a local force and a global force. The local force is used to guide each particle towards its local best position, while the global force is used to guide each particle towards the global best position. The algorithm terminates when the particles converge to the optimal solution. PSO is used in a variety of applications, including machine learning, image processing, and robotics.[7]</p>
#
# <p style="font-family:Georgia;"><B>Advantages of PSO: -</B></p>
# <ol style="font-family:Georgia;"><li>High scalability: Since particles interact only locally, the algorithm is highly scalable and can be applied to large problems.</li>
# <li>Fast convergence: The algorithm is quick to converge on good solutions, making it suitable for real-time applications.</li>
# <li> High flexibility: PSO is an inherently flexible algorithm, allowing for the incorporation of various parameters, and can be tailored to different kinds of problems.</li>
# <li> Robustness: PSO is robust to local minima and finds good solutions quickly even in the presence of noise.</li></ol>
#
# <p style="font-family:Georgia;"><B> Reason to choose PSO for given problem: - </B></p>
# <p style="font-family:Georgia;">Particle Swarm Optimization (PSO) is a heuristic search algorithm based on the collective behaviour of particles in a swarm. It is a population-based search algorithm that works on the principle of collaboration among different particles. PSO is suitable for the given problems since it is a multi-objective optimization algorithm that can be used to optimize complex problems with multiple objectives, such as the above two problems. PSO is also an iterative algorithm that can quickly and accurately identify potential solutions in the search space. Additionally, PSO is computationally efficient and is less prone to getting stuck in local optima.</p>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Methodology</p></H3>
# <ol style="font-family:Georgia;"><li>Importing the libraries for the implementation</li>
# <li>Visualizing the given Ground Stations</li>
# <li>Importing the dataset</li>
# <li>Visualizing the given flights and Ground Station</li>
# <li> Making the necessary modifications to the given dataset</li>
#     <ul style="font-family:Georgia;"><li> Converting the altitude to kms and latitude and logitude to radians</li>
#     <li> Adding columns to dataset </li></ul>
# <li>Creating necessary functions:-<ul><li>Cartesian</li>
#      <li>Euclidean Distance: -  To find the distance between two flights</li>
#      <li>Distance between Ground Stations and flights</li></ul>
# <li>Assigning flights to Ground Stations 1 and 2</li>
# <li> Plotting The flights allocated to Ground Stations</li>
# <li> Creating the functions for implementing the algorithms:- </li>
#       <ol style="font-family:Georgia;"><li> calculate end to end transmission rate</li>
#           <li> Route a population to routes</li>
#       <li> Making list of population size random flights</li>
#       <li> Fitness Function</li>
#       <li>Tournament Selection</li>
#       <li>Two-point Cross-over Selection Method with partial mapping</li>
#       <li>Scramble Mutation</li></ol>
# <li> Greedy Algorithm </li>
# <ol><li> Single Objective</li>
#     <li> Multi-Objective</li></ol>
# <li>Genetic ALgorithm</li>
# <ol><li> Single Objective</li>
#     <li> Multi-Objective</li></ol>
# <li> Particle Swarm Optimization</li>
# <ol><li> Single Objective</li>
#     <li> Multi-Objective</li></ol>
# <li>Comparing the Graphs</li>
# </ol>

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"> Importing the libraries for the implementation</p></H5>

# %%
from mpl_toolkits.basemap import Basemap #imports Basemap toolkit from the mpl_toolkits library for plotting 2D data on maps.[11]
import numpy as np  # provides functions for scientific computing
import matplotlib.pyplot as plt # for plotting the graphs
import pandas as pd # Data analysis and manipulation [10]
import math
import random
import copy

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"> Visualzing the given Ground Stations

# %%
min_latitude = 30
max_latitude = 70
min_longitude = -75
max_longitude = 5
fig = plt.figure(figsize=(12, 9))
ax = plt.axes()
map1 = Basemap(projection='merc', # Mercator Projection
            llcrnrlat=min_latitude,
            urcrnrlat=max_latitude,
            llcrnrlon=min_longitude,
            urcrnrlon=max_longitude)
map1.drawcoastlines(color='white', linewidth=0.2)  # add coastlines
map1.shadedrelief(scale=0.5)
map1.drawparallels(np.arange(-90, 90, 10), labels=[1, 0, 0, 0], zorder=1)
map1.drawmeridians(np.arange(-180, 180, 20), labels=[0, 0, 0, 1], zorder=2)

#LHR
XG1 =-0.4543
YG1 =51.4700
ZG1=81.73 

#EWR
XG2 =-74.1745
YG2 =40.6895  
ZG2=8.72 

latitudes = [YG1,YG2]
longitudes = [XG1,XG2]
altitudes = [ZG1,ZG2]

x, y = map1(longitudes, latitudes)  # transform coordinates
plt.scatter(x, y, 50, marker='v', color='Red') 
text_airport_LHR = ax.text(0, 0, '', c='b', zorder=5, bbox=dict(facecolor='w', alpha=0.5, edgecolor='w'))
text_airport_EWR = ax.text(0, 0, '', c='b', zorder=5, bbox=dict(facecolor='w', alpha=0.5, edgecolor='w'))
text_airport_LHR.set_position([x[0]*1.01, y[0]*1.01])
text_airport_EWR.set_position([x[1]*1.02, y[1]*1.02])
text_airport_LHR.set_text('LHR')
text_airport_EWR.set_text('EWR')

plt.title("North-Atlantic")
plt.show()

# %%
#LHR
XG1 =-0.4543
YG1 =51.4700
ZG1=81.73 

#EWR
XG2 =-74.1745
YG2 =40.6895  
ZG2=8.72

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"> Importing the Dataset

# %%
df = pd.read_csv(r'C:\Users\Tanmayee\OneDrive\Documents\Personal\SaO\NA_13_Jun_29_2018_UTC13.CSV')
print(df)
# Out:
#     Flight No.   Timestamp  Altitude  Latitude  Longitude
# 0        AA101  1530277200   39000.0      50.9      -38.7
# 1        AA109  1530277200   33000.0      60.3      -12.2
# 2        AA111  1530277200   39000.0      52.7      -18.1
# 3        AA113  1530277200   37000.0      43.0      -11.1
# 4        AA151  1530277200   36400.0      47.0      -27.7
# ..         ...         ...       ...       ...        ...
# 211      UA971  1530277200   32000.0      60.9      -29.9
# 212      UA973  1530277200   33000.0      61.0      -39.3
# 213      UA975  1530277200   36000.0      50.5      -26.4
# 214      UA986  1530277200   36000.0      60.0      -32.2
# 215      UA988  1530277200   36100.0      52.7      -18.8
#
# [216 rows x 5 columns]

# %%
df.rename(columns = {'Flight No.':'Flight_No'}, inplace = True) #Renaming the column for convenience

# %%
df.drop(['Timestamp'], axis=1, inplace=True) # Dropping the column from dataset as it is not used further

# %%
#Converting to Dataframe
df = pd.DataFrame(df)
df
# Out:
#     Flight_No  Altitude  Latitude  Longitude
# 0       AA101   39000.0      50.9      -38.7
# 1       AA109   33000.0      60.3      -12.2
# 2       AA111   39000.0      52.7      -18.1
# 3       AA113   37000.0      43.0      -11.1
# 4       AA151   36400.0      47.0      -27.7
# ..        ...       ...       ...        ...
# 211     UA971   32000.0      60.9      -29.9
# 212     UA973   33000.0      61.0      -39.3
# 213     UA975   36000.0      50.5      -26.4
# 214     UA986   36000.0      60.0      -32.2
# 215     UA988   36100.0      52.7      -18.8
#
# [216 rows x 4 columns]

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;">  Visualizing the given flights and Ground stations

# %%
#Visualizing the given flights on the map
min_latitude = 30
max_latitude = 70
min_longitude = -75
max_longitude = 5
fig = plt.figure(figsize=(12, 9))
ax = plt.axes()
map1 = Basemap(projection='merc', # Mercator Projection
            llcrnrlat=min_latitude,
            urcrnrlat=max_latitude,
            llcrnrlon=min_longitude,
            urcrnrlon=max_longitude)
map1.drawcoastlines(color='white', linewidth=0.2)  # add coastlines
map1.shadedrelief(scale=0.5)
map1.drawparallels(np.arange(-90, 90, 10), labels=[1, 0, 0, 0], zorder=1)
map1.drawmeridians(np.arange(-180, 180, 20), labels=[0, 0, 0, 1], zorder=2)


lats = df.Latitude.copy()
lons = df.Longitude.copy()
x, y = map1(lons, lats)

plt.scatter(x, y, 20, marker='*', color='blue') # * indicates the flight on the map
plt.show()

# %%
min_latitude = 30
max_latitude = 70
min_longitude = -75
max_longitude = 5
fig = plt.figure(figsize=(12, 9))
ax = plt.axes()
map1 = Basemap(projection='merc', # Mercator Projection
            llcrnrlat=min_latitude,
            urcrnrlat=max_latitude,
            llcrnrlon=min_longitude,
            urcrnrlon=max_longitude)
map1.drawcoastlines(color='white', linewidth=0.2)  # add coastlines
map1.shadedrelief(scale=0.5)
map1.drawparallels(np.arange(-90, 90, 10), labels=[1, 0, 0, 0], zorder=1)
map1.drawmeridians(np.arange(-180, 180, 20), labels=[0, 0, 0, 1], zorder=2)

latitudes = [YG1,YG2]
longitudes = [XG1,XG2]
altitudes = [ZG1,ZG2]
#lats = latitudes
#lons = longitudes

# compute n# make up some data for scatter plot
x, y = map1(longitudes, latitudes)  # transform coordinates
plt.scatter(x, y, 50, marker='v', color='Red') 
text_airport_LHR = ax.text(0, 0, '', c='black', zorder=5, bbox=dict(facecolor='w', alpha=0.5, edgecolor='w'))
text_airport_EWR = ax.text(0, 0, '', c='black', zorder=5, bbox=dict(facecolor='w', alpha=0.5, edgecolor='w'))
text_airport_LHR.set_position([x[0]*1.01, y[0]*1.01])
text_airport_EWR.set_position([x[1]*1.02, y[1]*1.02])
text_airport_LHR.set_text('LHR')
text_airport_EWR.set_text('EWR')


lats = df.Latitude.copy()
lons = df.Longitude.copy()
x, y = map1(lons, lats)

plt.scatter(x, y, 20, marker='*', color='blue') 
plt.title("North-Atlantic")
plt.show()

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Converting Altitude to km, Latitude and Longitude to radians</H3>
# <p style="font-family:Georgia;">In the given dataset the Altitude is given in feet. We need to convert feet into kilometers.
# So we multiply the given Altitudes by 0.3048
# So, df['Altitude'] holds the new value of altitude.</p>
# <p style="font-family:Georgia;">In the given dataset the Latitude and Longitude are given in degree. We need to degree feet into radians.
# So we multiply the given Latitudes and Longitude by 0.0174533
# So, df['Latitude'] and df['Longitude'] holds the new value of Latitude and Longitude.</p>

# %%
df['Altitude']=df['Altitude'].apply(lambda x:x*0.3048)
df['Latitude']=df['Latitude'].apply(lambda x:x*0.0174533)
df['Longitude']=df['Longitude'].apply(lambda x:x*0.0174533)
df
# Out:
#     Flight_No  Altitude  Latitude  Longitude
# 0       AA101  11887.20  0.888373  -0.675443
# 1       AA109  10058.40  1.052434  -0.212930
# 2       AA111  11887.20  0.919789  -0.315905
# 3       AA113  11277.60  0.750492  -0.193732
# 4       AA151  11094.72  0.820305  -0.483456
# ..        ...       ...       ...        ...
# 211     UA971   9753.60  1.062906  -0.521854
# 212     UA973  10058.40  1.064651  -0.685915
# 213     UA975  10972.80  0.881392  -0.460767
# 214     UA986  10972.80  1.047198  -0.561996
# 215     UA988  11003.28  0.919789  -0.328122
#
# [216 rows x 4 columns]

# %%
#Seperating the columns from the dataset
xy=df[['Longitude','Latitude','Altitude']]
xy
# Out:
#      Longitude  Latitude  Altitude
# 0    -0.675443  0.888373  11887.20
# 1    -0.212930  1.052434  10058.40
# 2    -0.315905  0.919789  11887.20
# 3    -0.193732  0.750492  11277.60
# 4    -0.483456  0.820305  11094.72
# ..         ...       ...       ...
# 211  -0.521854  1.062906   9753.60
# 212  -0.685915  1.064651  10058.40
# 213  -0.460767  0.881392  10972.80
# 214  -0.561996  1.047198  10972.80
# 215  -0.328122  0.919789  11003.28
#
# [216 rows x 3 columns]

# %%
#Adding columns XYZ
df["X"] = " " 
df["Y"] = " "
df["Z"] = " "
df
# Out:
#     Flight_No  Altitude  Latitude  Longitude  X  Y  Z
# 0       AA101  11887.20  0.888373  -0.675443
# 1       AA109  10058.40  1.052434  -0.212930
# 2       AA111  11887.20  0.919789  -0.315905
# 3       AA113  11277.60  0.750492  -0.193732
# 4       AA151  11094.72  0.820305  -0.483456
# ..        ...       ...       ...        ... .. .. ..
# 211     UA971   9753.60  1.062906  -0.521854
# 212     UA973  10058.40  1.064651  -0.685915
# 213     UA975  10972.80  0.881392  -0.460767
# 214     UA986  10972.80  1.047198  -0.561996
# 215     UA988  11003.28  0.919789  -0.328122
#
# [216 rows x 7 columns]

# %% [markdown]
# <H3><p style="font-family:Georgia;">Cartesian Function</H3>
# <p style="font-family:Georgia;"> In a three-dimensional Cartesian coordinate system, a point is represented by an ordered triple of real numbers (x, y, z). The x-coordinate specifies the horizontal position of the point, the y-coordinate specifies the vertical position of the point, and the z-coordinate specifies the depth of the point.
# </p>
# <p style="font-family:Georgia;">The Cartesian function formula for three sets of numbers is:</p>
# <p style="font-family:Georgia;">p<sub>x,a</sub> = (R<sub>E</sub> + L<sub>a</sub>) cos(θ<sub>a</sub>) cos(ϕ<sub>a</sub>)</p>
# <p style="font-family:Georgia;">p<sub>y,a</sub> = (R<sub>E</sub> + L<sub>a</sub>) cos(θ<sub>a</sub>) sin(ϕ<sub>a</sub>)</p>
# <p style="font-family:Georgia;">p<sub>z,a</sub> = (R<sub>E</sub> + L<sub>a</sub>) sin(θ<sub>a</sub>)

# %%
#Creating Cartesian Function to convert the Latitude, Longitude and Altitude values to Cartesian form
def cartesian_conv(Lo, La, Al):
  R = 6378137
  X = (R + Al) * math.cos(La) * math.cos(Lo)
  Y =  (R + Al) * math.cos(La) * math.sin(Lo)
  Z =  (R + Al) * math.sin(La)  
  return (X,Y,Z)

# %%
#Getting the cartesian distance in the XYZ Columns
for index, row in df.iterrows():
    X,Y,Z = cartesian_conv(row['Longitude'],row['Latitude'],row['Altitude'])

    df['X'].iloc[index]=X
    df['Y'].iloc[index]=Y
    df['Z'].iloc[index]=Z
# Out:
# C:\Users\Tanmayee\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.head(10)
# Out:
#   Flight_No  Altitude  Latitude  Longitude               X               Y  \
# 0     AA101  11887.20  0.888373  -0.675443    3145158.6172 -2519748.688071
# 1     AA109  10058.40  1.052434  -0.212930  3093603.624618  -668861.074332
# 2     AA111  11887.20  0.919789  -0.315905   3680661.50556 -1203026.169312
# 3     AA113  11277.60  0.750492  -0.193732  4585502.646488  -899640.247392
# 4     AA151  11094.72  0.820305  -0.483456  3858052.644868 -2025523.941713
# 5     AA198      0.00  0.696387  -1.274091  1430596.526953  -4679279.53468
# 6     AA199  11277.60  0.926770  -0.415389  3510088.524692 -1548134.247505
# 7     AA204      0.00  0.701623  -1.284563  1375450.507738 -4673389.413248
# 8     AA209  11582.40  1.015782  -1.029745  1734182.040416 -2886166.473707
# 9     AA221  10363.20  1.041962  -0.904081  1993235.867228 -2532952.991287
#
#                 Z
# 0  4958956.855852
# 1  5548989.272433
# 2   5083096.31957
# 3  4357571.781969
# 4   4672789.80084
# 5  4091255.089109
# ...

# %%
# Creating Euclidean Distance function to find the Distance between 2 flights
def Euclidean_dis(A1, A2):
  # fetch the x1 , y1, z1 
  X1,Y1,Z1 = df.iloc[A1]['X'],df.iloc[A1]['Y'],df.iloc[A1]['Z']
  X2,Y2,Z2 =df.iloc[A2]['X'],df.iloc[A2]['Y'],df.iloc[A2]['Z']
  d=math.sqrt(((X1-X2)**2)+((Y1-Y2)**2)+((Z1-Z2)**2))
  return(d)

# %%
#Giving the flight index number to find distance euclidean between two flights
Euclidean_dis(10,145)
# Out:
# 2303948.673582623

# %% [markdown]
# <H5><p style="font-family:Georgia;">Why is it necessary to convert to Cartesian Co-ordinates?</H5>
# <ol style="font-family:Georgia;"><li>Compatibility with algorithms: Many algorithms and mathematical formulas are designed to work with Cartesian coordinates, so it may be necessary to convert other types of coordinates (such as polar or spherical coordinates) to Cartesian coordinates in order to use these algorithms.</li>
# <li>Data analysis: Cartesian coordinates are often used to represent data points in graphs and plots, making it easier to visualize trends and relationships in the data.</li>

# %%
#Converting the Ground Station values to Cartesian Coordinates
XGS1, YGS1, ZGS1=cartesian_conv(XG1*0.0174533, YG1*0.0174533, ZG1*0.305) 

#Converting to Cartesian Coordinates
XGS2, YGS2, ZGS2=cartesian_conv(XG2*0.0174533, YG2*0.0174533, ZG2*0.305)

# %% [markdown]
# <H5><p style="font-family:Georgia;">ED_GS1_to_A</H5>
# <p style="font-family:Georgia;">Function called ED_GS1_to_A that calculates the Euclidean distance between a point represented by variables XGS1, YGS1, and ZGS1 and another point represented by variables X, Y, and Z. The function takes a single argument A, which is the index of the second point in a dataframe df.
# The function begins by extracting the values of X, Y, and Z from the dataframe using the index A. It then calculates the Euclidean distance between the two points using the formula:
# <p style="font-family:Georgia;">d = √((X<sub>GS1</sub> - X)<sup>2</sup> + (Y<sub>GS1</sub> - Y)<sup>2</sup> + (Z<sub>GS1</sub> - Z)<sup>2</sup>)
# <p style="font-family:Georgia;">where d is the distance between the points (X<sub>GS1</sub>, Y<sub>GS1</sub>, Z<sub>GS1</sub>) and (X, Y, Z).
# <p style="font-family:Georgia;">Finally, the function returns the calculated distance d as the output.</p>

# %%
# Distance between GS1 flights
def ED_GS1_to_A(A):
  # fetch the x1 , y z, 
  X,Y,Z = df.iloc[A]['X'],df.iloc[A]['Y'],df.iloc[A]['Z']
  d=math.sqrt(((XGS1-X)**2)+((YGS1-Y)**2)+((ZGS1-Z)**2))
  return(d)

# %%
# Checking the distance between Ground Station 1 and the flight
ED_GS1_to_A(5)
# Out:
# 5373309.748048101

# %%
# Distance between GS2 flights
def ED_GS2_to_A(A):
  # fetch the x1 , y z, 
  X,Y,Z = df.iloc[A]['X'],df.iloc[A]['Y'],df.iloc[A]['Z']
  d=math.sqrt(((XGS2-X)**2)+((YGS2-Y)**2)+((ZGS2-Z)**2))
  return(d)

# %%
ED_GS2_to_A(5)
# Out:
# 132918.83121827143

# %% [markdown]
# <p style="font-family:Georgia;">Below code defines a list called flight_list which contains the values of the Flight_No column from a dataframe df.</p>
# <p style="font-family:Georgia;">The values attribute of the Flight_No column returns an array of the values in the column.
# <p style="font-family:Georgia;">The tolist() method is then used to convert this array to a Python list.

# %%
#Creating list of Flight_No
flight_list=df['Flight_No'].values.tolist()
flight_list
# Out:
# ['AA101',
#  'AA109',
#  'AA111',
#  'AA113',
#  'AA151',
#  'AA198',
#  'AA199',
#  'AA204',
#  'AA209',
#  'AA221',
#  'AA25',
#  'AA258',
#  'AA259',
#  'AA291',
#  'AA37',
#  'AA39',
#  'AA45',
#  'AA47',
#  'AA51',
#  'AA53',
#  'AA57',
#  'AA67',
#  'AA705',
#  'AA71',
#  'AA715',
#  'AA717',
#  'AA719',
#  'AA721',
#  'AA723',
#  'AA725',
#  'AA731',
#  'AA735',
#  'AA741',
#  'AA743',
#  'AA745',
#  'AA749',
#  'AA751',
#  'AA755',
#  'AA759',
#  'AA87',
#  'AA93',
#  'AA97',
#  'BA117',
#  'BA173',
#  'BA174',
#  'BA175',
#  'BA178',
#  'BA179',
#  'BA185',
#  'BA191',
#  'BA193',
#  'BA2037',
#  'BA207',
#  'BA212',
#  'BA213',
#  'BA2155',
#  'BA2167',
#  'BA217',
#  'BA2239',
#  'BA225',
#  'BA2271',
#  'BA2277',
#  'BA238',
#  'BA239',
#  'BA244',
#  'BA249',
#  'BA250',
#  'BA283',
#  'BA285',
#  'BA287',
#  'BA295',
#  'BA49',
#  'BA53',
#  'BA67',
#  'BA801',
#  'BA93',
#  'DL107',
#  'DL109',
#  'DL11',
#  'DL117',
#  'DL118',
#  'DL131',
#  'DL133',
#  'DL136',
# ...

# %% [markdown]
# <H5><p style="font-family:Georgia;"> Assigning flights to Ground Stations 1 and 2</H5>
# <p style="font-family:Georgia;">Below code iterates through each row of a dataframe df using the iterrows() method. For each row, it calculates the Euclidean distance between two points using two functions: ED_GS1_to_A and ED_GS2_to_A. These functions take an index as an argument and return the Euclidean distance between the point represented by the index and another fixed point.
# <p style="font-family:Georgia;">For each row, the code compares the distances calculated by the two functions and appends the index of the row to one of two lists: FGS1 or FGS2. If the distance calculated by ED_GS1_to_A is less than the distance calculated by ED_GS2_to_A, the index is appended to FGS1. If the distance calculated by ED_GS2_to_A is less than the distance calculated by ED_GS1_to_A, the index is appended to FGS2.
# <p style="font-family:Georgia;">This code effectively partition the rows of the dataframe df into two groups based on which of the two points is closer to each row.

# %%
#Assignment of flight to GS1 or GS2
FGS1=[]
FGS2=[]

for index, row in df.iterrows():
    distance1=ED_GS1_to_A(index)
    distance2=ED_GS2_to_A(index)
    
    if distance1 < distance2:
        FGS1.append(index)
    else: 
        FGS2.append(index)
        
        # df.iloc[index]['Flight_No']

# %%
#Number of Flights assigned to GS1 and GS2
a = len(FGS1) #calculates the length of FGS1
b = len(FGS2)
print(a,b)
# Out:
# 146 70

# %% [markdown]
# <p style="font-family:Georgia;">Below code iterates through a list FGS1 and extracts the values of the Latitude and Longitude columns for each element (which is an index) in the list. It then appends the extracted values to two lists: Lat_GS1 and Lon_GS1, respectively.
# <p style="font-family:Georgia;">The iloc attribute of the dataframe df is used to access rows of the dataframe using their integer indices. For example, df.iloc[flight]['Latitude'] retrieves the value of the Latitude column for the row with index flight.
# <p style="font-family:Georgia;">Creates two lists containing the Latitude and Longitude values for a subset of the rows in the dataframe df.

# %%
# Seperating the Flight details of flights allocated to GS1
Lat_GS1=[]
Lon_GS1=[]
for flight in FGS1:
    lat = df.iloc[flight]['Latitude']
    lon = df.iloc[flight]['Longitude']
    Lat_GS1.append(lat)
    Lon_GS1.append(lon)

# %% [markdown]
# <H5><p style="font-family:Georgia;"> Creates a new dataframe with two columns: 'Latitude' and 'Longitude', and populates it with the values from the Lat_GS1 and Lon_GS1 lists.</H5>
# <p style="font-family:Georgia;">Creates two Pandas dataframes: lats and lons. It then concatenates these dataframes into a third dataframe called det.
# <p style="font-family:Georgia;">The lats dataframe is created using a dictionary containing a single key-value pair: 'Latitude' is the key and (Lat_GS1) is the value. The lons dataframe is created in a similar manner, using a dictionary with the key 'Longitude' and the value (Lon_GS1).
# <p style="font-family:Georgia;">The pd.concat() function is used to concatenate the two dataframes lats and lons along the columns (axis = 1). The join parameter specifies the type of join to use when concatenating the dataframes. The value 'outer' specifies an outer join, which includes all rows from both dataframes, even if they have missing values in some columns.
# <p style="font-family:Georgia;">Finally, the det dataframe is printed.

# %%
# Creating seperate column to hold the values of Latitude and Longitude of GS1
lats = pd.DataFrame({'Latitude':(Lat_GS1)})
lons = pd.DataFrame({'Longitude':(Lon_GS1)})
det = pd.concat([lats, lons], join = 'outer', axis = 1)
det
# Out:
#      Latitude  Longitude
# 0    0.888373  -0.675443
# 1    1.052434  -0.212930
# 2    0.919789  -0.315905
# 3    0.750492  -0.193732
# 4    0.820305  -0.483456
# ..        ...        ...
# 141  1.062906  -0.521854
# 142  1.064651  -0.685915
# 143  0.881392  -0.460767
# 144  1.047198  -0.561996
# 145  0.919789  -0.328122
#
# [146 rows x 2 columns]

# %%
# Seperating the Flight details of flights allocated to GS1
Lat_GS2=[]
Lon_GS2=[]
for flight in FGS2:
    lat = df.iloc[flight]['Latitude']
    lon = df.iloc[flight]['Longitude']
    Lat_GS2.append(lat)
    Lon_GS2.append(lon)
    
    
# Creating seperate column to hold the values of Latitude and Longitude of GS2
lats_2 = pd.DataFrame({'Latitude':(Lat_GS2)})
lons_2 = pd.DataFrame({'Longitude':(Lon_GS2)})
det_2 = pd.concat([lats_2, lons_2], join = 'outer', axis = 1)
det_2
# Out:
#     Latitude  Longitude
# 0   0.696387  -1.274091
# 1   0.701623  -1.284563
# 2   1.015782  -1.029745
# 3   1.041962  -0.904081
# 4   0.893609  -0.753983
# ..       ...        ...
# 65  0.849976  -0.975639
# 66  0.890118  -0.776672
# 67  0.849976  -0.977385
# 68  0.750492  -0.869174
# 69  0.884882  -0.811578
#
# [70 rows x 2 columns]

# %% [markdown]
# <H3><p style="font-family:Georgia;">Visualising the Flights Allocated to Ground Station 1 and Ground Station 2</H3>

# %%
plt.figure(figsize=(12,10))

for flight in FGS1:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot1= plt.scatter(x,y,marker='*',c='c')

for flight in FGS2:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot2= plt.scatter(x,y,marker='*',c='navy')
    
plot3 = plt.scatter(XGS1,YGS1,c='black',marker='v',s=300)
plot4 = plt.scatter(XGS2,YGS2,c='red',marker='^',s=300)
plt.xlabel('x-cartesian')
plt.ylabel('y-cartesian')
plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
           scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
plt.show(block=True)

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;"> Creating the functions for implementing the algorithms

# %% [markdown]
# <p style="font-family:Georgia;"><B>Function to calculate end to end transmission rate</B>
# <p style="font-family:Georgia;">Code defines a function called tr_rate that takes a list of indices list_path as an argument and returns a rate value. The function calculates the rate by iterating through the indices in list_path, calculating the Euclidean distance between each pair of indices using the Euclidean_dis function, and determining the rate based on the distance calculated.
# <p style="font-family:Georgia;">The function begins by initializing the variable best_rate to 0 and the variable GS to the last element in the list_path list. It then iterates through the indices in list_path, excluding the first and last indices, using a for loop. For each index, it calculates the distance between the current index and the next index using the Euclidean_dis function.
# <p style="font-family:Georgia;">Based on the calculated distance, the function determines a rate value using a series of if-elif statements. If the distance is greater than 500,000, the rate is set to 31.895. If the distance is between 400,000 and 500,000, the rate is set to 43.505, and so on.
# <p style="font-family:Georgia;">The function then compares the rate value to the current value of best_rate and updates best_rate if the current rate is lower. This process continues until all indices have been processed.
# <p style="font-family:Georgia;">Finally, the function calculates the distance between the second-to-last index in list_path and one of the two fixed points (either "GS1" or "GS2") using the ED_GS1_to_A or ED_GS2_to_A function, depending on the value of GS. It then determines a rate value based on this distance using a series of if-elif statements, similar to the ones used earlier.

# %%
#function to calculate end to end transmission rate
def tr_rate(list_path):
    best_rate=0
    GS = list_path[-1]
    for i in range(len(list_path)-2):
        d = Euclidean_dis(list_path[i],list_path[i+1])
        if d > 500000:
            r=31.895
        elif 500000 > d > 400000:
            r = 43.505
        elif 400000> d > 300000:
            r = 52.857
        elif 300000 > d > 190000:
            r = 63.970
        elif 190000 > d > 90000:
            r = 77.071
        elif 90000 > d > 35000:
            r = 93.854
        elif 35000 > d:
            r = 119.130
        if i == 0:
            best_rate = r
        elif r < best_rate : 
            best_rate = r

    if GS == "GS1":
        dis = ED_GS1_to_A(list_path[-2]) 
    elif GS == "GS2" : 
        dis = ED_GS2_to_A(list_path[-2]) 
    if dis > 500000:
        r = 31.895
    elif 500000 > dis > 400000:
        r = 43.505
    elif 400000 > dis > 300000:
        r = 52.857
    elif 300000 > dis > 190000:
        r = 63.970
    elif 190000 > dis > 90000:
        r = 77.071
    elif 90000 > dis > 35000:
        r = 93.854
    elif 35000 > dis :
        r = 119.130 
    if r < best_rate or best_rate == 0: 
            best_rate = r
    return(best_rate)

# %% [markdown]
# <p style="font-family:Georgia;"><B>Route a population to routes</B>
# <p style="font-family:Georgia;">Function dividingroutes that takes a list of flight indices flightlist and a string GS as arguments and returns a list of routes.
# <p style="font-family:Georgia;">The function iterates through the flights in flightlist and for each flight, it calculates the Euclidean distance between the last flight in the current route (represented by the list single_route) and the current flight, as well as the distance between the last flight in the current route and one of the two fixed points ("GS1" or "GS2"). It then compares the distances and decides whether to add the current flight to the current route or to start a new route. If the distance between the current flight and the last flight in the current route is less than the distance between the last flight in the current route and the fixed point, the current flight is added to the current route. If the distance between the current flight and the last flight in the current route is greater than or equal to the distance between the last flight in the current route and the fixed point, the current route is terminated and a new route is started.

# %%
# Route a population to routes
def dividingroutes(flightlist, GS):
    list_of_routes = []
    single_route = []
    
    # looping through all flights to be added to list
    for flight in flightlist:
        if len(single_route) == 0:
            single_route.append(flight)
        else:
            last_flight = single_route[-1]
            
            # find distnace between flights
            
            d1 = Euclidean_dis(last_flight, flight)
            
            # find distnace between flight and GS
            if GS == 'GS1':   
                d2 = ED_GS1_to_A(last_flight)
            elif GS == 'GS2':
                d2 = ED_GS2_to_A(last_flight)
            
            # compare the distances
            #print(d1,d2), and (d2-d1) > 350000
            if d1 < d2 :
                single_route.append(flight)
            else:
                single_route.append(GS)
                list_of_routes.append(single_route)
                single_route = []
                
    return list_of_routes

# %% [markdown]
# <H5 style="color:brown;"><p style="font-family:Georgia;"> Implementation of Greedy Algorithm

# %% [markdown]
# <p style="font-family:Georgia;">The function first initializes a variable d to be the Euclidean distance between the flight and the first flight in the flight_list. It also initializes a variable nextf to be the first flight in the flight_list.
# <p style="font-family:Georgia;">Then, the function iterates through the rest of the flights in flight_list, starting from the second flight. For each of these flights, it calculates the Euclidean distance between the flight and the current flight and compares it to the current value of d. If the distance is smaller than d, then the function updates d to be the new distance and updates nextf to be the current flight.
# <p style="font-family:Georgia;">Finally, the function returns nextf, which is the flight in flight_list that is closest to the flight according to the Euclidean distance.

# %%
# Find next flight
def nextflight(flight, flight_list):
    d = Euclidean_dis(flight, flight_list[0])
    nextf = flight_list[0]
    for f in flight_list[1:]:
        d1 = Euclidean_dis(flight, flight_list[0])
        if d1 < d:
            d = d1
            nextf = f
    return nextf

# %% [markdown]
# <p style="font-family:Georgia;">The function begins by initializing two variables: 'GS and node'. If point1 is in the list of ground stations ("GS1" or "GS2"), then GS is set to point1 and node is set to point2. If point2 is in the list of ground stations, then GS is set to point2 and node is set to point1. If neither point1 nor point2 are in the list of ground stations, then GS is set to None.
# <p style="font-family:Georgia;">If GS is not None, then the function calculates the distance between the ground station and node using one of two functions: ED_GS1_to_A or ED_GS2_to_A. If GS is None, then the function calculates the Euclidean distance between point1 and point2 using a function called Euclidean_dis.
# <p style="font-family:Georgia;">After calculating the distance, the function uses a series of if statements to determine the data rate r based on the distance. If the distance is greater than 500000, then r is set to 31.895. If the distance is between 500000 and 400000, then r is set to 43.505, and so on. Finally, the function returns r.

# %%
def datarate2points(point1, point2):
    GS_list = ["GS1", "GS2"]
    GS = None
    if point1 in GS_list:
        GS = point1
        node = point2
    elif point2 in GS_list:
        GS = point2
        node = point1
    
    if GS != None:
        if GS == "GS1":
            d = ED_GS1_to_A(node) 
        elif GS == "GS2" : 
            d = ED_GS2_to_A(node) 
    else:
        d = Euclidean_dis(point1, point2)
        
    if d > 500000:
        r=31.895
    elif 500000 > d > 400000:
        r = 43.505
    elif 400000> d > 300000:
        r = 52.857
    elif 300000 > d > 190000:
        r = 63.970
    elif 190000 > d > 90000:
        r = 77.071
    elif 90000 > d > 35000:
        r = 93.854
    elif 35000 > d :
        r = 119.130
    return r

# %% [markdown]
# <p style="font-family:Georgia;">The function begins by initializing an empty list called routes which will be used to store all routing paths. It also initializes a variable called currentfl to be equal to GS, a list called visited_list to store the flights that have already been visited, and a variable route which will be used to store the current routing path.
#
# <p style="font-family:Georgia;">The function enters a loop that continues until currentfl becomes None. Inside the loop, the function checks whether currentfl is equal to GS. If it is, it selects the first flight in flight_list that has not been visited and sets currentfl to be this flight. It also initializes route to be a list containing only this flight and adds the flight to the visited_list. If all flights in flight_list have been visited, the function sets currentfl to be None to exit the loop.
#
# <p style="font-family:Georgia;">If currentfl is not GS, then the function calculates the data transmission rate for the current routing path route plus the ground station GS. It then finds the next flight with the maximum data transmission rate from the current location using the nextflight function, which returns the next closest flight in flight_list that has not yet been visited. The function also calculates the data rate between the current flight and the next flight using the datarate2points function.
#
# <p style="font-family:Georgia;">If the data rate between the current flight and the next flight is equal to the data transmission rate for the current routing path, then the function adds the next flight to the current routing path and marks it as visited. If the data rate is not equal to the data transmission rate, then the function adds the ground station to the current routing path, appends the routing path to the routes list, and sets the current flight back to the ground station.
#
# <p style="font-family:Georgia;">Finally, the function returns the list of all routing paths, routes.

# %%
def greedy1(flight_list, GS):
    # Create an empty list to store all routing paths
    routes = []
    currentfl = GS
    visited_list = []
    # While the current location is not a GS
    while currentfl != None:
        if currentfl == GS:
            currentfl = list(set(flight_list) - set(visited_list))[0]
            route = [currentfl]
            visited_list.append(currentfl)
            if len(flight_list) == len(visited_list):
                    currentfl = None
        else:
            # Find the next flight with the maximum data transmission rate from the current location
            routerate = tr_rate(route + [GS])
            nextfl = nextflight(currentfl, list(set(flight_list) - set(visited_list)))
            nextdrate = datarate2points(currentfl, nextfl)
            
            # only add the flight if it maintains the datarate
            if nextdrate == routerate:
                route.append(nextfl)
                visited_list.append(nextfl)
                currentfl = nextfl
                if len(flight_list) == len(visited_list):
                    currentfl = None

            else: 
                route.append(GS)
                routes.append(route)
                currentfl = GS
    return routes

# %% [markdown]
# <p style="font-family:Georgia;">This code defines a function called greedy2 that is similar to the greedy1 function described in the previous answer, but with a small modification. The main difference is that the greedy2 function only adds a flight to the current routing path if the data rate between the current flight and the next flight is greater than or equal to the data transmission rate for the current routing path and the data rate is not equal to 31.895.
#
# <p style="font-family:Georgia;">Otherwise, the function behaves the same way as the greedy1 function. It continues to select the next closest flight in flight_list that has not yet been visited, calculates the data rate between the current flight and the next flight, and adds the next flight to the routing path if the data rate meets the requirements. If the data rate does not meet the requirements, then the function adds the ground station to the routing path, appends the routing path to the routes list, and sets the current flight back to the ground station.
#
# <p style="font-family:Georgia;">Finally, the function returns the list of all routing paths, routes.

# %%
def greedy2(flight_list, GS):
    # Create an empty list to store all routing paths
    routes = []
    currentfl = GS
    visited_list = []
    # While the current location is not a GS
    while currentfl != None:
       
        if currentfl == GS:
            currentfl = list(set(flight_list) - set(visited_list))[0]
            route = [currentfl]
            visited_list.append(currentfl)
            if len(flight_list) == len(visited_list):
                    currentfl = None
        else:
            # Find the next flight with the maximum data transmission rate from the current location
            routerate = tr_rate(route + [GS])
            nextfl = nextflight(currentfl, list(set(flight_list) - set(visited_list)))
            nextdrate = datarate2points(currentfl, nextfl)
            
            # only add the flight if it maintains the datarate and latency
            if nextdrate >= routerate and (nextdrate != 31.895):
                route.append(nextfl)
                visited_list.append(nextfl)
                currentfl = nextfl
                if len(flight_list) == len(visited_list):
                    currentfl = None

            else: 
                route.append(GS)
                routes.append(route)
                currentfl = GS
    return routes

# %%
# Main single objective GS1 using Greedy
GREEDY_GS1_SO = greedy1(FGS1,"GS1")

# %%
# Main single objective GS2 using Greedy
GREEDY_GS2_SO = greedy1(FGS2,"GS2")

# %% [markdown]
# <p style="font-family:Georgia;">The variable trs is defined as an empty list. The code then enters a for loop that iterates over the concatenation of the GREEDY_GS1_SO and GREEDY_GS2_SO variables. For each route in this concatenated list, the code calls a function tr_rate with the route as an argument and assigns the result to a variable tr. The value of tr is then appended to the trs list.
#
# <p style="font-family:Georgia;">After the loop completes, the code converts the trs list to a set and assigns the result to trs_set. The code then enters a for loop that iterates over trs_set and prints the transmission rate v and the frequency at which it appears in the trs list.

# %%
# Finding the Transmission Rate
trs = []
for route in GREEDY_GS1_SO + GREEDY_GS2_SO:
    tr = tr_rate(route)
    trs.append(tr)
trs_set = set(trs)
print('Transmission rate')
for v in trs_set:
    print(v, ':',trs.count(v))
# Out:
# Transmission rate
# 93.854 : 2
# 77.071 : 2
# 52.857 : 1
# 31.895 : 25

# %%
Route_Greedy1 = GREEDY_GS1_SO + GREEDY_GS2_SO
Route_Greedy1
# Out:
# [[0, 1, 2, 3, 4, 6, 11, 12, 15, 19, 23, 24, 'GS1'],
#  [26, 27, 28, 30, 'GS1'],
#  [31, 32, 33, 34, 35, 36, 38, 39, 40, 41, 43, 47, 48, 49, 'GS1'],
#  [50, 51, 52, 54, 55, 57, 58, 59, 60, 'GS1'],
#  [61, 63, 65, 67, 68, 69, 70, 71, 73, 74, 75, 76, 77, 78, 79, 'GS1'],
#  [81, 84, 87, 89, 'GS1'],
#  [91, 92, 'GS1'],
#  [93, 95, 96, 97, 99, 'GS1'],
#  [100, 101, 104, 105, 107, 129, 131, 132, 133, 'GS1'],
#  [135, 136, 138, 139, 140, 142, 'GS1'],
#  [144, 'GS1'],
#  [146, 147, 148, 'GS1'],
#  [149, 151, 152, 153, 'GS1'],
#  [154,
#   155,
#   157,
#   158,
#   159,
#   160,
#   161,
#   163,
#   164,
#   165,
#   166,
#   167,
#   169,
#   170,
#   172,
#   173,
#   174,
#   175,
#   176,
#   177,
#   178,
#   179,
#   181,
#   182,
#   183,
#   184,
#   185,
#   187,
#   188,
#   189,
#   190,
#   191,
#   193,
#   194,
#   195,
#   197,
#   200,
#   201,
#   'GS1'],
#  [202, 203, 204, 109, 205, 'GS1'],
#  [206, 207, 112, 209, 211, 212, 213, 214, 215, 'GS1'],
#  [5, 'GS2'],
# ...

# %% [markdown]
# <H3><p style="font-family:Georgia;">Plotting the Routing for the Greedy Algorithm for Single Objective</H3>

# %%
plt.figure(figsize=(20,16))

for flight in FGS1:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot1= plt.scatter(x,y,c='c')

for flight in FGS2:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot2= plt.scatter(x,y,c='g')
    
plot3 = plt.scatter(XGS1,YGS1,c='black',marker='v',s=300)
plot4 = plt.scatter(XGS2,YGS2,c='red',marker='^',s=300)

random.shuffle(Route_Greedy1) # change the Route for all outputs
plot_route = []
k = 0
for route in Route_Greedy1:
    if len(route)> 3:
        plot_route.append(route)
        k+=1
    if k == 4:
        break

k = 0
for route in plot_route:
    color={1:'c',2:'b',3:'m',4:'r'}
    k+=1
    for i in range(1,len(route)):
        
        x1= df.loc[route[i-1],'X']
        y1= df.loc[route[i-1],'Y']
        
        if route[i] == 'GS1':
            x2 = XGS1
            y2 = YGS1
        elif route[i] == 'GS2':
            x2 = XGS2
            y2 = YGS2
        else:
            x2= df.loc[route[i],'X']
            y2= df.loc[route[i],'Y']
        plt.plot([x1,x2],[y1,y2],color=color[k])
        
        
plt.xlabel('x-cartesian')
plt.ylabel('y-cartesian')
plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
           scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
plt.show(block=True)

# %%
# Main multi objective GS1 using Greedy
GREEDY_GS1_MO = greedy2(FGS1,"GS1")

# %%
# Main multi objective GS2 using Greedy
GREEDY_GS2_MO = greedy2(FGS2,"GS2")

# %% [markdown]
# <p style="font-family:Georgia;">The variables trs and las are defined as empty lists. The code then enters a for loop that iterates over the concatenation of the GREEDY_GS1_MO and GREEDY_GS2_MO variables. For each route in this concatenated list, the code calls a function tr_rate with the route as an argument and assigns the result to a variable tr. The code then calculates the latency la as 50 times the number of edges in the route minus 1. The values of tr and la are then appended to the trs and las lists, respectively.
#
# <p style="font-family:Georgia;">After the loop completes, the code converts the trs list to a set and assigns the result to trs_set. The code then enters a for loop that iterates over trs_set and prints the transmission rate v and the frequency at which it appears in the trs list.
#
# <p style="font-family:Georgia;">The code then prints a newline and the string 'Latency', followed by another for loop that iterates over the las_set set (which is created by converting the las list to a set) and prints the latency v and the frequency at which it appears in the las list.

# %%
trs = []
las = []
for route in GREEDY_GS1_MO + GREEDY_GS2_MO:
    tr = tr_rate(route)
    la = 50 * (len(route)-1)
    trs.append(tr)
    las.append(la)
trs_set = set(trs)
print('Transmission rate')
for v in trs_set:
    print(v, ':',trs.count(v))
print('\n Latency')
las_set = set(las)
for v in las_set:
    print(v, ':',las.count(v))
# Out:
# Transmission rate
# 43.505 : 1
# 77.071 : 6
# 52.857 : 6
# 119.13 : 6
# 31.895 : 165
# 93.854 : 4
# 63.97 : 2
#
#  Latency
# 50 : 167
# 100 : 22
# 150 : 1

# %%
Route_Greedy2 = GREEDY_GS1_MO + GREEDY_GS2_MO
Route_Greedy2
# Out:
# [[0, 'GS1'],
#  [1, 'GS1'],
#  [2, 'GS1'],
#  [3, 'GS1'],
#  [4, 'GS1'],
#  [6, 'GS1'],
#  [11, 'GS1'],
#  [12, 'GS1'],
#  [15, 'GS1'],
#  [19, 'GS1'],
#  [23, 'GS1'],
#  [24, 26, 'GS1'],
#  [27, 'GS1'],
#  [28, 'GS1'],
#  [30, 31, 'GS1'],
#  [32, 'GS1'],
#  [33, 'GS1'],
#  [34, 'GS1'],
#  [35, 'GS1'],
#  [36, 'GS1'],
#  [38, 'GS1'],
#  [39, 'GS1'],
#  [40, 'GS1'],
#  [41, 'GS1'],
#  [43, 'GS1'],
#  [47, 'GS1'],
#  [48, 'GS1'],
#  [49, 50, 'GS1'],
#  [51, 'GS1'],
#  [52, 'GS1'],
#  [54, 'GS1'],
#  [55, 'GS1'],
#  [57, 'GS1'],
#  [58, 'GS1'],
#  [59, 'GS1'],
#  [60, 61, 'GS1'],
#  [63, 'GS1'],
#  [65, 'GS1'],
#  [67, 'GS1'],
#  [68, 'GS1'],
#  [69, 'GS1'],
#  [70, 'GS1'],
#  [71, 'GS1'],
#  [73, 'GS1'],
#  [74, 'GS1'],
#  [75, 'GS1'],
#  [76, 'GS1'],
#  [77, 'GS1'],
#  [78, 'GS1'],
#  [79, 81, 'GS1'],
#  [84, 'GS1'],
#  [87, 'GS1'],
#  [89, 91, 'GS1'],
#  [92, 93, 'GS1'],
#  [95, 'GS1'],
#  [96, 'GS1'],
#  [97, 'GS1'],
#  [99, 100, 'GS1'],
#  [101, 'GS1'],
#  [104, 'GS1'],
# ...

# %% [markdown]
# <H3><p style="font-family:Georgia;">Plotting the Routing for the Greedy Algorithm for Multi Objective</H3>

# %%
plt.figure(figsize=(20,16))

for flight in FGS1:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot1= plt.scatter(x,y,c='c')

for flight in FGS2:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot2= plt.scatter(x,y,c='g')
    
plot3 = plt.scatter(XGS1,YGS1,c='black',marker='v',s=300)
plot4 = plt.scatter(XGS2,YGS2,c='red',marker='^',s=300)
# plt.xlabel('x-cartesian')
# plt.ylabel('y-cartesian')
# plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
#            scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
random.shuffle(Route_Greedy2) # change the Route for all outputs
plot_route = []
k = 0
for route in Route_Greedy2:
    if len(route)> 2:
        plot_route.append(route)
        k+=1
    if k == 3:
        break

k = 0
for route in plot_route:
    color={1:'c',2:'b',3:'m',4:'r',5:'y',6:'g'}
    k+=1
    for i in range(1,len(route)):
        
        x1= df.loc[route[i-1],'X']
        y1= df.loc[route[i-1],'Y']
        
        if route[i] == 'GS1':
            x2 = XGS1
            y2 = YGS1
        elif route[i] == 'GS2':
            x2 = XGS2
            y2 = YGS2
        else:
            x2= df.loc[route[i],'X']
            y2= df.loc[route[i],'Y']
        plt.plot([x1,x2],[y1,y2],color=color[k])
        
        
plt.xlabel('x-cartesian')
plt.ylabel('y-cartesian')
plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
           scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
plt.show(block=True)

# %% [markdown]
# <H5 style="color:brown;"><p style="font-family:Georgia;"> Implementation of Genetic Algorithm

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"><B>Initial population: -</B></p></H5>
# <p style="font-family:Georgia;">A population, a group of people, is where the process starts. Every person is a component of the answer to the issue you're trying to address. Genes are a set of factors (variables) that define an individual. A chromosome is made up of a string of genes (solution). A string, or an alphabet, is used in a genetic algorithm to represent a person's collection of genes. Binary values are typically utilised (string of 1s and 0s). We refer to the genes on a chromosome as being encoded.<p style="font-family:Georgia;">

# %%
# Making list of population size random flights
def pop_int(flight_list,pop_size):
    pop = []
    for i in range(pop_size):
        link = []
        for j in range(len(flight_list)):
            link.append(flight_list[j])
        random.shuffle(link)    
        pop.append(link)
    return(pop)

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"><B>Fitness function</B></p></H5>
# <p style="font-family:Georgia;">The fitness function evaluates an individual’s level of fitness (the ability of an individual to compete with other individuals). Each individual receives a fitness rating from the system. Based on its fitness score, an individual's likelihood of being chosen for reproduction is determined.
# Our Fitness assessment function determines the data transmission rate and one path from point of initialization in order to solve the problem of maximising the end-to-end transmission rate, which is directly proportional to the minimum distance between two flights.<p style="font-family:Georgia;">

# %%
# Fitness Function for Single Objective Optimization
def fit_fn_SO(link,GS):
    
    list_of_routes = dividingroutes(link,GS)
    list_of_rate = []
    best_rate=0
    for list_path in list_of_routes:

        for i in range(len(list_path)-2):
            d = Euclidean_dis(list_path[i],list_path[i+1])

            if d > 500000:
                r=31.895
            elif 500000 > d > 400000:
                r = 43.505
            elif 400000> d > 300000:
                r = 52.857
            elif 300000 > d > 190000:
                r = 63.970
            elif 190000 > d > 90000:
                r = 77.071
            elif 90000 > d > 35000:
                r = 93.854
            elif 35000 > d :
                r = 119.130
            if i == 0:
                best_rate = r
            elif r < best_rate : 
                best_rate = r
   
        if GS == "GS1":
            dis = ED_GS1_to_A(list_path[-2]) 
        elif GS == "GS2": 
            dis = ED_GS2_to_A(list_path[-2]) 
            
        if dis > 500000:
            r=31.895
        elif 500000 > dis > 400000:
            r = 43.505
        elif 400000> dis > 300000:
            r = 52.857
        elif 300000 > dis > 190000:
            r = 63.970
        elif 190000 > dis > 90000:
            r = 77.071
        elif 90000 > dis > 35000:
            r = 93.854
        elif 35000 > dis:
            r = 119.130 
        if r < best_rate or best_rate == 0 : 
                best_rate = r
        
        list_of_rate.append(best_rate)
        best_rate = 0
    
    average_rate = sum(list_of_rate)/len(list_of_rate)
   
    return(list_of_routes, average_rate)

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"><B>Weighted sum Method</B></p></H5>
# <p style="font-family:Georgia;">The weighted sum method is a technique used to evaluate and compare multiple options or alternatives based on multiple criteria. It involves assigning weights to the criteria, calculating a score for each alternative based on its performance on the criteria, and summing the scores to obtain a overall score for each alternative.
# <p style="font-family:Georgia;">The formula for the weighted sum method is:
# <p style="font-family:Georgia;">Overall score = ∑(Weight<sub>i</sub> × Score<sub>i</sub>)
# <p style="font-family:Georgia;">where:
# <p style="font-family:Georgia;">Overall score is the overall score for the alternative being evaluated.
# <p style="font-family:Georgia;">Weight<sub>i</sub> is the weight assigned to criterion i.
# <p style="font-family:Georgia;">Score<sub>i</sub> is the score for the alternative on criterion i.
# <p style="font-family:Georgia;">The overall score is calculated by summing the products of the weights and scores for each criterion. The weights reflect the relative importance of the criteria in the decision-making process, and the scores reflect the performance of the alternative on each criterion.

# %%
# Fitness Function for Multiple Objective Optimization
def fit_fn_MO(link,GS):
    
    list_of_routes = dividingroutes(link,GS)
    list_of_rate = []
    list_of_latency = []
    best_rate=0
    for list_path in list_of_routes:

        for i in range(len(list_path)-2):
            d = Euclidean_dis(list_path[i],list_path[i+1])
            if d > 500000:
                r=31.895
            elif 500000 > d > 400000:
                r = 43.505
            elif 400000> d > 300000:
                r = 52.857
            elif 300000 > d > 190000:
                r = 63.970
            elif 190000 > d > 90000:
                r = 77.071
            elif 90000 > d > 35000:
                r = 93.854
            elif 35000 > d:
                r = 119.130
            if i == 0:
                best_rate = r
            elif r < best_rate : 
                best_rate = r
                
        if GS == "GS1":
            dis = ED_GS1_to_A(list_path[-2]) 
        elif GS == "GS2": 
            dis = ED_GS2_to_A(list_path[-2]) 
        if dis > 500000:
            r=31.895
        elif 500000 > dis > 400000:
            r = 43.505
        elif 400000> dis > 300000:
            r = 52.857
        elif 300000 > dis > 190000:
            r = 63.970
        elif 190000 > dis > 90000:
            r = 77.071
        elif 90000 > dis > 35000:
            r = 93.854
        elif 35000 > dis:
            r = 119.130 
        if r < best_rate or best_rate == 0: 
                best_rate = r
        
        list_of_rate.append(best_rate)
        best_rate = 0
        
        latency = 50 * (len(list_path)-1)
        list_of_latency.append(latency)
    
    average_rate = sum(list_of_rate)/len(list_of_rate)
    average_latency = sum(list_of_latency)/len(list_of_rate)
    
    # Weighted sum method 
    fitness = 0.5 * average_rate + 0.5 * average_latency
        
    return(list_of_routes, fitness)

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"><B>Tournament Selection</B></p></H5>
# <p style="font-family:Georgia;">The purpose of the selection phase is to choose the most fit people and allow them to pass on their genes to the following generation. Based on their fitness ratings, two sets of people (parents) are chosen. High fitness people are more likely to be chosen for reproduction.
# The tournament selection approach, where the best or fittest flights are chosen as parents and compete against one random chosen Ground Station.<p style="font-family:Georgia;">

# %%
# Tournament Selection
def tour_sel(population,GS):
    parents = []
    num_of_parents = round(len(population)/2)
    if num_of_parents % 2 != 0:
        num_of_parents += 1
    copying_pop = copy.copy(population)
    for z in range(0,num_of_parents):
        p1,p2=random.sample(copying_pop,2)
        fitness_p1 =fit_fn_SO(p1,GS)
        fitness_p2 =fit_fn_SO(p2,GS)
        
        if fitness_p1[1]>fitness_p2[1]:
            parents.append(p1)
            copying_pop.remove(p1)
        else :
            parents.append(p2)
            copying_pop.remove(p2)
    return parents

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"><B>Two Point Crossover</B></p></H5>
# <p style="font-family:Georgia;">The important phase of a genetic algorithm is crossover. A crossover point is picked at random from the genes for each set of parents to mate.
# Two-point cross-over selection method with partial mapping is an efficient way of selecting genes for recombination in genetic algorithms. It is advantageous over other methods because it helps reduce the complexity of the selection process by using a simpler algorithm. The method also helps reduce the chances of introducing undesirable traits into the population and can help reduce the time taken to find a solution. Additionally, it also helps speed up the convergence of the population towards a more optimal solution.</p>

# %%
# Two-point Cross-over Selection Method with partial mapping

def crossover(population):
    
    children = []
    for i in range(0,len(population),2):
        # get the parents 
        p1 = population[i]
        p2 = population[i+1]
        
        # chose two cross over points
        r1 = random.randint(2, int(0.75 * len(p1)))
        r2 = random.randint(r1, len(p1)-2)
        
        # give the corresponding points to child
        c1 = p1[:r1] + p2[r1:r2] + p1[r2:]
        c2 = p2[:r1] + p1[r1:r2] + p2[r2:]
        
        # partial mapping to avoid repitiotion
        for i in range(len(c1)):
            if  i < r1 or i >= r2:       
                f = c1[i]
                while f in c1[r1:r2]:
                    for g in c1[r1:r2]:
                        if g == f:    
                            ind = c1[r1:r2].index(g) + r1
                            break
                    f = c2[ind]
                c1[i] = f
                
        for i in range(len(c2)):
            if  i < r1 or i >= r2:       
                f = c2[i]
                while f in c2[r1:r2]:
                    for g in c2[r1:r2]:
                        if g == f:    
                            ind = c2[r1:r2].index(g) + r1
                            break
                    f = c1[ind]
                c2[i] = f
                
        children.append(c1)
        children.append(c2)
    return(children)

# %% [markdown]
# <H5 style="color:teal;"><p style="font-family:Georgia;"><B>Scramble Mutation</B></p></H5>
# <p style="font-family:Georgia;">Scramble mutation is a type of genetic algorithm mutation which randomly reorders a section of the chromosome. It is a useful technique for searching a large number of solutions in a short amount of time. It can be used to solve complex problems, such as optimization and scheduling. Additionally, it is beneficial for use in multi-objective optimization, as it allows for a wider range of solutions to be explored.</p>

# %%
# Scramble Mutation

def scramble_mut(population):
    
    scrambled =[]
    for f in population:
        r1 = random.randint(0, int(0.75 * len(f)))
        r2 = random.randint(r1, len(f))
        
        scramble = f[r1:r2]
        random.shuffle(scramble)
        s = f[:r1] + scramble + f[r2:]
        
        scrambled.append(s)
    return(scrambled)

# %%
# Genetic algorithm for single-objective optimization

def geneticalgo(flight_list,pop_size, GS, generation):
    
    # Initialize population
    population = pop_int(flight_list,pop_size)

    # find fitness of initial population
    fitnessbest = 0
    routebest = []
    fitnessvsgen = []
    for link in population:
        routes, fitness = fit_fn_SO(link,GS)
        
        if fitness > fitnessbest:
            fitnessbest = fitness
            routebest = routes
    
    fitnessvsgen.append(fitnessbest)
    print(f'initial population fitness: {fitnessbest}')
    
    # create generations
    for i in range(generation):

        # select parents
        parents = tour_sel(population,GS)
        
        # crossover childs
        childs = crossover(parents)
        
        # mutate childs
        scrambled = scramble_mut(childs)
        
        # new generation
        population = parents + scrambled
        
        # find fitness in current generation
        for link in population:
            routes, fitness = fit_fn_SO(link,GS)

            if fitness > fitnessbest:
                fitnessbest = fitness
                routebest = routes
                
        fitnessvsgen.append(fitnessbest)       
        print(f'{i + 1} generation fitness: {fitnessbest}')
        
    return(fitnessbest, routebest, fitnessvsgen)

# %%
# Genetic algorithm for single-objective optimization

def geneticalgo(flight_list,pop_size, GS, generation):
    
    # Initialize population
    population = pop_int(flight_list,pop_size)

    # find fitness of initial population
    fitnessbest = 0
    routebest = []
    fitnessvsgen = []
    for link in population:
        routes, fitness = fit_fn_SO(link,GS)
        
        if fitness > fitnessbest:
            fitnessbest = fitness
            routebest = routes
    
    fitnessvsgen.append(fitnessbest)
    print(f'initial population fitness: {fitnessbest}')
    
    # create generations
    for i in range(generation):

        # select parents
        parents = tour_sel(population,GS)
        
        # crossover childs
        childs = crossover(parents)
        
        # mutate childs
        scrambled = scramble_mut(childs)
        
        # new generation
        population = parents + scrambled
        
        # find fitness in current generation
        for link in population:
            routes, fitness = fit_fn_SO(link,GS)

            if fitness > fitnessbest:
                fitnessbest = fitness
                routebest = routes
                
        fitnessvsgen.append(fitnessbest)       
        print(f'{i + 1} generation fitness: {fitnessbest}')
        
    return(fitnessbest, routebest, fitnessvsgen)

# %%
# genetic algorithm for multi-objective optimization

def geneticalgo2(flight_list,pop_size, GS, generation):
    
    # Initialize population
    population = pop_int(flight_list,pop_size)

    # find fitness of initial population
    fitnessbest = 0
    routebest = []
    fitnessvsgen = []
    for link in population:
        routes, fitness = fit_fn_MO(link,GS)
        
        if fitness > fitnessbest:
            fitnessbest = fitness
            routebest = routes
    
    fitnessvsgen.append(fitnessbest)
    print(f'initial population fitness: {fitnessbest}')
    
    # create generations
    for i in range(generation):

        # select parents
        parents = tour_sel(population,GS)
        
        # crossover childs
        childs = crossover(parents)
        
        # mutate childs
        scrambled = scramble_mut(childs)
        
        # new generation
        population = parents + scrambled
        
        # find fitness in current generation
        for link in population:
            routes, fitness = fit_fn_MO(link,GS)

            if fitness > fitnessbest:
                fitnessbest = fitness
                routebest = routes
                
        fitnessvsgen.append(fitnessbest)       
        print(f'{i + 1} generation fitness: {fitnessbest}')
        
    return(fitnessbest, routebest, fitnessvsgen)

# %% [markdown]
# <H5 style="color:black;"><p style="font-family:Georgia;">Main single objective GS1 using GA</H5>
# <p style="font-family:Georgia;">The code above is calling the geneticalgo function with the arguments FGS1, 10, "GS1", and 50.
# <p style="font-family:Georgia;">The geneticalgo function is a function that performs a genetic algorithm optimization on a given list of flight indices (FGS1 in this case) to find the best routes for the flights. The function takes four arguments:
# <p style="font-family:Georgia;">FGS1: a list of flight indices
# <p style="font-family:Georgia;">10: an integer representing the size of the population
# <p style="font-family:Georgia;">"GS1": a string representing the fixed point
# <p style="font-family:Georgia;">50: an integer representing the number of generations to run the algorithm
# <p style="font-family:Georgia;">The function returns the best routes and the fitness of the best solution found by the algorithm.

# %%
# Main single objective GS1 using GA
GA_GS1_SO = geneticalgo(FGS1,10, "GS1", 50)
# Out:
# initial population fitness: 45.08211904761904
# 1 generation fitness: 45.08211904761904
# 2 generation fitness: 45.08211904761904
# 3 generation fitness: 45.08211904761904
# 4 generation fitness: 45.08211904761904
# 5 generation fitness: 45.08211904761904
# 6 generation fitness: 45.08211904761904
# 7 generation fitness: 45.08211904761904
# 8 generation fitness: 45.08211904761904
# 9 generation fitness: 45.08211904761904
# 10 generation fitness: 45.08211904761904
# 11 generation fitness: 45.08211904761904
# 12 generation fitness: 45.172365853658526
# 13 generation fitness: 45.172365853658526
# 14 generation fitness: 45.172365853658526
# 15 generation fitness: 45.172365853658526
# 16 generation fitness: 46.67223076923076
# 17 generation fitness: 46.67223076923076
# 18 generation fitness: 46.67223076923076
# 19 generation fitness: 46.67223076923076
# 20 generation fitness: 46.67223076923076
# 21 generation fitness: 46.67223076923076
# 22 generation fitness: 46.67223076923076
# ...

# %%
# Main single objective GS2 using GA
GA_GS2_SO = geneticalgo(FGS2,10, "GS2", 50)
# Out:
# initial population fitness: 46.30866666666665
# 1 generation fitness: 46.30866666666665
# 2 generation fitness: 46.30866666666665
# 3 generation fitness: 46.33581249999999
# 4 generation fitness: 46.33581249999999
# 5 generation fitness: 48.11037499999999
# 6 generation fitness: 48.11037499999999
# 7 generation fitness: 48.11037499999999
# 8 generation fitness: 48.11037499999999
# 9 generation fitness: 48.11037499999999
# 10 generation fitness: 48.11037499999999
# 11 generation fitness: 48.11037499999999
# 12 generation fitness: 48.11037499999999
# 13 generation fitness: 50.061449999999994
# 14 generation fitness: 50.061449999999994
# 15 generation fitness: 50.061449999999994
# 16 generation fitness: 50.061449999999994
# 17 generation fitness: 50.061449999999994
# 18 generation fitness: 50.061449999999994
# 19 generation fitness: 50.061449999999994
# 20 generation fitness: 50.061449999999994
# 21 generation fitness: 50.061449999999994
# 22 generation fitness: 50.20825
# ...

# %%
#Plotting the single objective functions fitness for Ground Station 1
# using subplot function and creating plot one
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)
plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(GA_GS1_SO[2], 'g', linewidth=1, linestyle='-')
plt.title('Single Objective of GS1')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2)
plt.plot(GA_GS2_SO[2], 'g', linewidth=1, linestyle='-')
plt.title('Single-Objective of GS2')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# space between the plots
plt.tight_layout(4)
 
# show plot
plt.show()
# Out:
# C:\Users\Tanmayee\AppData\Local\Temp/ipykernel_27608/1548998980.py:22: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %% [markdown]
# <p style="font-family:Georgia;">Below code is defining an empty list called trs and then iterating through the routes in the first element of the tuple returned by the geneticalgo function when it is called with FGS1 as the first argument (GA_GS1_SO[1]) and the routes in the first element of the tuple returned by the geneticalgo function when it is called with FGS2 as the first argument (GA_GS2_SO[1]). For each route, the code calls the tr_rate function with the route as an argument and appends the return value to the trs list.
# <p style="font-family:Georgia;">After all the routes have been processed, the code converts the trs list to a set and then iterates through the unique values in the set. For each unique value, it prints the value and the number of times it appears in the trs list.
# <p style="font-family:Georgia;">The tr_rate function returns the transmission rate for a given route, which is a real number representing the cost of transmitting the data in the route. The transmission rate is calculated based on the distance between the fixed point and the last flight in the route.

# %%
# Finding the Transmission Rate
trs = []
for route in GA_GS1_SO[1] + GA_GS2_SO[1]:
    tr = tr_rate(route)
    trs.append(tr)
trs_set = set(trs)
print('Transmission rate')
for v in trs_set:
    print(v, ':',trs.count(v))
# Out:
# Transmission rate
# 77.071 : 2
# 52.857 : 2
# 119.13 : 6
# 93.854 : 4
# 31.895 : 40

# %% [markdown]
# <p style="font-family:Georgia;">The Routes1 list will contain the routes found by the geneticalgo function when it was called with FGS1 as the first argument and the routes found by the geneticalgo function when it was called with FGS2 as the first argument.

# %%
Route_GA1 = GA_GS1_SO[1] + GA_GS2_SO[1]
Route_GA1
# Out:
# [[63, 'GS1'],
#  [191, 181, 'GS1'],
#  [132, 'GS1'],
#  [136, 93, 159, 74, 'GS1'],
#  [12, 140, 206, 209, 6, 51, 55, 'GS1'],
#  [120, 188, 41, 89, 'GS1'],
#  [109, 24, 'GS1'],
#  [214, 43, 163, 'GS1'],
#  [71, 'GS1'],
#  [59, 'GS1'],
#  [211, 129, 31, 'GS1'],
#  [160, 95, 149, 178, 'GS1'],
#  [158, 144, 78, 'GS1'],
#  [207, 49, 54, 'GS1'],
#  [197, 4, 40, 193, 'GS1'],
#  [58, 176, 'GS1'],
#  [195, 190, 194, 'GS1'],
#  [15, 'GS1'],
#  [203, 52, 32, 19, 92, 48, 133, 164, 200, 28, 153, 154, 185, 189, 'GS1'],
#  [179, 138, 73, 'GS1'],
#  [39, 187, 174, 87, 151, 131, 213, 30, 2, 84, 'GS1'],
#  [68, 182, 79, 81, 104, 205, 3, 'GS1'],
#  [165, 'GS1'],
#  [201, 96, 'GS1'],
#  [212, 107, 139, 'GS1'],
#  [204, 'GS1'],
#  [166, 101, 'GS1'],
#  [152, 'GS1'],
#  [77, 167, 'GS1'],
#  [69, 'GS1'],
#  [47, 'GS1'],
#  [146, 'GS1'],
#  [157, 'GS1'],
#  [122, 'GS1'],
#  [67, 161, 'GS1'],
#  [75, 'GS1'],
#  [35, 100, 'GS1'],
#  [99, 'GS1'],
#  [168, 21, 186, 22, 'GS2'],
#  [145, 'GS2'],
#  [7, 'GS2'],
# ...

# %% [markdown]
# <H3><p style="font-family:Georgia;">Plotting the Routing for the Genetic Algorithm for Single Objective</H3>

# %%
plt.figure(figsize=(20,16))

for flight in FGS1:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot1= plt.scatter(x,y,c='c')

for flight in FGS2:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot2= plt.scatter(x,y,c='g')
    
plot3 = plt.scatter(XGS1,YGS1,c='black',marker='v',s=300)
plot4 = plt.scatter(XGS2,YGS2,c='red',marker='^',s=300)
# plt.xlabel('x-cartesian')
# plt.ylabel('y-cartesian')
# plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
#            scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
random.shuffle(Route_GA1) # change the Route for all outputs
plot_route = []
k = 0
for route in Route_GA1:
    if len(route)> 5:
        plot_route.append(route)
        k+=1
    if k == 6:
        break

k = 0
for route in plot_route:
    color={1:'c',2:'b',3:'m',4:'r',5:'g',6:'y'}
    k+=1
    for i in range(1,len(route)):
        
        x1= df.loc[route[i-1],'X']
        y1= df.loc[route[i-1],'Y']
        
        if route[i] == 'GS1':
            x2 = XGS1
            y2 = YGS1
        elif route[i] == 'GS2':
            x2 = XGS2
            y2 = YGS2
        else:
            x2= df.loc[route[i],'X']
            y2= df.loc[route[i],'Y']
        plt.plot([x1,x2],[y1,y2],color=color[k])
        
        
plt.xlabel('x-cartesian')
plt.ylabel('y-cartesian')
plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
           scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
plt.show(block=True)

# %%
# Main multi objective GS1 using GA
GA_GS1_MO = geneticalgo2(FGS1,10, "GS1", 50)
# Out:
# initial population fitness: 93.88130555555554
# 1 generation fitness: 95.28139999999999
# 2 generation fitness: 101.41375
# 3 generation fitness: 101.41375
# 4 generation fitness: 101.41375
# 5 generation fitness: 101.41375
# 6 generation fitness: 101.41375
# 7 generation fitness: 101.45841176470587
# 8 generation fitness: 101.45841176470587
# 9 generation fitness: 101.45841176470587
# 10 generation fitness: 101.45841176470587
# 11 generation fitness: 101.45841176470587
# 12 generation fitness: 101.45841176470587
# 13 generation fitness: 101.45841176470587
# 14 generation fitness: 101.45841176470587
# 15 generation fitness: 101.45841176470587
# 16 generation fitness: 101.45841176470587
# 17 generation fitness: 101.45841176470587
# 18 generation fitness: 101.45841176470587
# 19 generation fitness: 101.45841176470587
# 20 generation fitness: 101.45841176470587
# 21 generation fitness: 101.45841176470587
# 22 generation fitness: 101.45841176470587
# ...

# %%
# Main multi objective GS2 using GA
GA_GS2_MO = geneticalgo2(FGS2,10, "GS2", 50)
# Out:
# initial population fitness: 97.26971875
# 1 generation fitness: 97.26971875
# 2 generation fitness: 97.26971875
# 3 generation fitness: 97.26971875
# 4 generation fitness: 98.2265294117647
# 5 generation fitness: 98.49132352941176
# 6 generation fitness: 98.49132352941176
# 7 generation fitness: 106.64623333333333
# 8 generation fitness: 106.64623333333333
# 9 generation fitness: 106.64623333333333
# 10 generation fitness: 106.64623333333333
# 11 generation fitness: 106.64623333333333
# 12 generation fitness: 106.64623333333333
# 13 generation fitness: 106.64623333333333
# 14 generation fitness: 106.64623333333333
# 15 generation fitness: 106.64623333333333
# 16 generation fitness: 106.64623333333333
# 17 generation fitness: 106.64623333333333
# 18 generation fitness: 106.64623333333333
# 19 generation fitness: 106.64623333333333
# 20 generation fitness: 106.64623333333333
# 21 generation fitness: 106.64623333333333
# 22 generation fitness: 106.64623333333333
# ...

# %%
#Plotting the Multi objective functions fitness for Ground Station 1
# using subplot function and creating plot one
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)
plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(GA_GS1_MO[2], 'b', linewidth=1, linestyle='-')
plt.title('Multi Objective of GS1')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2)
plt.plot(GA_GS2_MO[2], 'b', linewidth=1, linestyle='-')
plt.title('Multi-Objective of GS2')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# space between the plots
plt.tight_layout(4)
 
# show plot
plt.show()
# Out:
# C:\Users\Tanmayee\AppData\Local\Temp/ipykernel_27608/1475863068.py:22: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %% [markdown]
# <p style="font-family:Georgia;">Below code is analyzing the routes produced by the geneticalgo function when it is called with FGS1 and FGS2 as the first argument. It is calculating the transmission rate and latency for each route and then printing out the frequency of different transmission rates and latencies that appear in the routes. The transmission rate is calculated based on the distance between the fixed point and the last flight in the route, and the latency is calculated as the number of flights in the route multiplied by 50.

# %%
trs = []
las = []
for route in GA_GS1_MO[1] + GA_GS2_MO[1]:
    tr = tr_rate(route)
    la = 50 * (len(route)-1)
    trs.append(tr)
    las.append(la)
trs_set = set(trs)
print('Transmission rate')
for v in trs_set:
    print(v, ':',trs.count(v))
print('\n Latency')
las_set = set(las)
for v in las_set:
    print(v, ':',las.count(v))
# Out:
# Transmission rate
# 119.13 : 4
# 77.071 : 2
# 93.854 : 1
# 31.895 : 40
#
#  Latency
# 450 : 1
# 100 : 9
# 550 : 2
# 200 : 4
# 300 : 2
# 400 : 1
# 50 : 14
# 500 : 1
# 150 : 8
# 250 : 3
# 350 : 2

# %%
Route_GA2 = GA_GS1_MO[1] + GA_GS2_MO[1]
Route_GA2
# Out:
# [[19, 201, 211, 181, 'GS1'],
#  [52, 30, 81, 167, 178, 'GS1'],
#  [63, 'GS1'],
#  [129, 54, 'GS1'],
#  [184, 120, 204, 'GS1'],
#  [2, 139, 'GS1'],
#  [153, 'GS1'],
#  [38, 166, 39, 202, 182, 209, 195, 48, 40, 189, 'GS1'],
#  [36, 165, 'GS1'],
#  [59, 'GS1'],
#  [172, 84, 157, 'GS1'],
#  [213, 104, 176, 151, 206, 47, 'GS1'],
#  [136, 60, 163, 146, 'GS1'],
#  [123, 'GS1'],
#  [214, 58, 'GS1'],
#  [125, 'GS1'],
#  [91, 193, 'GS1'],
#  [190, 207, 31, 27, 205, 0, 112, 159, 169, 140, 1, 'GS1'],
#  [203, 'GS1'],
#  [69, 'GS1'],
#  [33, 97, 'GS1'],
#  [191, 174, 105, 122, 3, 11, 75, 'GS1'],
#  [12, 197, 77, 170, 87, 61, 'GS1'],
#  [164, 6, 152, 'GS1'],
#  [50, 142, 78, 'GS1'],
#  [41, 109, 161, 'GS1'],
#  [160, 57, 132, 89, 'GS1'],
#  [35, 158, 187, 68, 15, 'GS1'],
#  [51, 'GS1'],
#  [99, 'GS1'],
#  [26, 107, 101, 'GS1'],
#  [71, 'GS1'],
#  [133, 177, 93, 74, 'GS1'],
#  [17, 83, 121, 14, 150, 110, 21, 208, 20, 8, 53, 'GS2'],
#  [82, 111, 'GS2'],
#  [98, 'GS2'],
#  [42, 116, 'GS2'],
# ...

# %% [markdown]
# <H3><p style="font-family:Georgia;">Plotting the Routing for the Genetic Algorithm for Multiple Objective</H3>

# %%
plt.figure(figsize=(20,16))

for flight in FGS1:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot1= plt.scatter(x,y,c='c')

for flight in FGS2:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot2= plt.scatter(x,y,c='g')
    
plot3 = plt.scatter(XGS1,YGS1,c='black',marker='v',s=300)
plot4 = plt.scatter(XGS2,YGS2,c='red',marker='^',s=300)
# plt.xlabel('x-cartesian')
# plt.ylabel('y-cartesian')
# plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
#            scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
random.shuffle(Route_GA2) # change the Route for all outputs
plot_route = []
k = 0
for route in Route_GA2:
    if len(route)> 5:
        plot_route.append(route)
        k+=1
    if k == 6:
        break

k = 0
for route in plot_route:
    color={1:'c',2:'b',3:'m',4:'r',5:'g',6:'y'}
    k+=1
    for i in range(1,len(route)):
        
        x1= df.loc[route[i-1],'X']
        y1= df.loc[route[i-1],'Y']
        
        if route[i] == 'GS1':
            x2 = XGS1
            y2 = YGS1
        elif route[i] == 'GS2':
            x2 = XGS2
            y2 = YGS2
        else:
            x2= df.loc[route[i],'X']
            y2= df.loc[route[i],'Y']
        plt.plot([x1,x2],[y1,y2],color=color[k])
        
        
plt.xlabel('x-cartesian')
plt.ylabel('y-cartesian')
plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
           scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
plt.show(block=True)

# %% [markdown]
# <H5 style="color:brown;"><p style="font-family:Georgia;"> Implementation of Praticle Swarm Optimization

# %% [markdown]
# <H5 style="color:black;"><p style="font-family:Georgia;">Single objective optimization</H5>
# <H5 style="color:navy;"><p style="font-family:Georgia;">Intitalize Particles</H5>
# <p style="font-family:Georgia;"> Defines a function called pso that takes a list of flight indices, an integer representing the size of the population, a string representing the fixed point, an integer representing the number of generations to run the particle swarm optimization algorithm, and two real numbers as arguments. The function does not return anything.
#
# <p style="font-family:Georgia;"> The function initializes a list of particles and calculates the fitness of each particle using a helper function. It then compares the fitness of each particle with the current global best fitness and updates the global best if necessary. The global best is a list that stores the particle with the highest fitness and its fitness. The function also stores the global best fitness in a list and prints the initial population fitness.
#
# <p style="font-family:Georgia;">A loop that iterates through the particles and generates a new velocity for each particle based on its previous velocity and the global best particle. The velocity is a list of swap pairs, where each swap pair represents a pair of indices that will be swapped in the particle.
# <H5 style="color:Navy;"><p style="font-family:Georgia;">Find the personal & global fitness </H5>
# <p style="font-family:Georgia;">The code iterates through the indices of the particle and checks if the flight at the current index is different from the flight at the same index in the personal best particle (the particle with the highest fitness among all the particles that the current particle has had in its history). If the flights are different, a swap pair is added to the velocity list.
# <H5 style="color:Navy;"><p style="font-family:Georgia;">Velocity & position update for pBest</H5>
# <p style="font-family:Georgia;">After the velocity list is created, the code iterates through the swap pairs in the velocity list and performs a random swap for each pair with a probability equal to 1 - beta. This means that the swap will be performed with a probability of beta and not performed with a probability of 1 - beta.
# For each generation, the code iterates through the particles and generates a new velocity for each particle based on its previous velocity and the global best particle. The velocity is a list of swap pairs, where each swap pair represents a pair of indices that will be swapped in the particle.
# <p style="font-family:Georgia;">The code then calculates the fitness of the particle using a helper function and updates the personal best and global best if necessary. The personal best is a list that stores the particle with the highest fitness among all the particles that the current particle has had in its history, and the global best is a list that stores the particle with the highest fitness among all the particles.
# <p style="font-family:Georgia;">After all the particles have been updated, the code appends the global best fitness to a list and prints the fitness of the current generation.
# <p style="font-family:Georgia;">Finally, the function returns the global best fitness, the routes of the global best particle, and the list of global best fitnesses for each generation.

# %%
# particle swarm single objective optimization algorithm

def pso(flight_list, pop_size, GS, generation, alpha, beta):
    
    # Initialize particles
    particles = pop_int(flight_list,pop_size)
        
    # Find the personal & global fitness 
    pBest = []
    fitnessvsgen = []
    gBest = []
    for p in particles:
        routes, fitness = fit_fn_SO(p,GS)
        pBest.append([p, fitness])
        if len(gBest) == 0:
            gBest = [p, fitness]
        elif gBest[1] < fitness:
            gBest = [p,fitness,routes]

    fitnessvsgen.append(gBest[1])
    print(f'initial population fitness: {gBest[1]}')

    # create generations
    for i in range(generation):
        
        for j in range(len(particles)):
            particle = particles[j]
            pBest_particle = pBest[j][0]
            pBest_fitness = pBest[j][1]
            gBest_particle = gBest[0]
            gBest_fitness = gBest[1]

            # Velocity & position update for pBest

            velocity = []
            for k in range(len(particle)):
                if particle[k] != pBest_particle[k]: 
                    # create a swap pair
                    velocity.append((k, pBest_particle.index(particle[k])))
            
            for swap in velocity:
                ran = random.random()
                if ran > beta:
                    particle[swap[0]],particle[swap[1]] =particle[swap[1]],particle[swap[0]]
                    
            # Velocity & position update for gBest
            velocity = []
            for k in range(len(particle)):
                if particle[k] != gBest_particle[k]: 
                    # create a swap op
                    velocity.append((k, gBest_particle.index(particle[k])))
            
            for swap in velocity:
                ran = random.random()
                if ran > alpha:
                    particle[swap[0]],particle[swap[1]] =particle[swap[1]],particle[swap[0]]
                

            # Find the personal & global fitness  
            routes, fitness = fit_fn_SO(particle,GS)

            if fitness > pBest_fitness:
                pBest[j] = [particle, fitness]

            if fitness > gBest_fitness:
                gBest = [particle, fitness, routes]

        
        fitnessvsgen.append(gBest[1])
        print(f'{i + 1} generation fitness: {gBest[1]}')


    return(gBest[1], gBest[2], fitnessvsgen)

# %% [markdown]
# <H7 style="color:black;"><p style="font-family:Georgia;"><B> Particle swarm multi objective optimization algorithm

# %%
# particle swarm optimization algorithm

def pso2(flight_list, pop_size, GS, generation, alpha, beta):
    
    # Initialize particles
    particles = pop_int(flight_list,pop_size)
        
    # Find the personal & global fitness 
    pBest = []
    fitnessvsgen = []
    gBest = []
    for p in particles:
        routes, fitness = fit_fn_MO(p,GS)
        pBest.append([p, fitness])
        if len(gBest) == 0:
            gBest = [p, fitness]
        elif gBest[1] < fitness:
            gBest = [p,fitness,routes]

    fitnessvsgen.append(gBest[1])
    print(f'initial population fitness: {gBest[1]}')

    # create generations
    for i in range(generation):
        
        for j in range(len(particles)):
            particle = particles[j]
            pBest_particle = pBest[j][0]
            pBest_fitness = pBest[j][1]
            gBest_particle = gBest[0]
            gBest_fitness = gBest[1]

            # Velocity & position update for pBest

            velocity = []
            for k in range(len(particle)):
                if particle[k] != pBest_particle[k]: 
                    # create a swap pair
                    velocity.append((k, pBest_particle.index(particle[k])))
            
            for swap in velocity:
                ran = random.random()
                if ran > beta:
                    particle[swap[0]],particle[swap[1]] =particle[swap[1]],particle[swap[0]]
                    
            # Velocity & position update for gBest
            velocity = []
            for k in range(len(particle)):
                if particle[k] != gBest_particle[k]: 
                    # create a swap op
                    velocity.append((k, gBest_particle.index(particle[k])))
            
            for swap in velocity:
                ran = random.random()
                if ran > alpha:
                    particle[swap[0]],particle[swap[1]] =particle[swap[1]],particle[swap[0]]
                

            # Find the personal & global fitness  
            routes, fitness = fit_fn_MO(particle,GS)

            if fitness > pBest_fitness:
                pBest[j] = [particle, fitness]

            if fitness > gBest_fitness:
                gBest = [particle, fitness, routes]

        
        fitnessvsgen.append(gBest[1])
        print(f'{i + 1} generation fitness: {gBest[1]}')


    return(gBest[1], gBest[2], fitnessvsgen)

# %%
# Main single objective GS1 using PSO
PSO_GS1_SO = pso(FGS1, 10, 'GS1', 50, 0.3, 0.5)
# Out:
# initial population fitness: 41.46102499999999
# 1 generation fitness: 41.702846153846146
# 2 generation fitness: 42.781395348837194
# 3 generation fitness: 42.781395348837194
# 4 generation fitness: 45.657999999999994
# 5 generation fitness: 47.43657777777777
# 6 generation fitness: 47.43657777777777
# 7 generation fitness: 47.43657777777777
# 8 generation fitness: 49.37927499999999
# 9 generation fitness: 50.299499999999995
# 10 generation fitness: 50.299499999999995
# 11 generation fitness: 50.299499999999995
# 12 generation fitness: 50.299499999999995
# 13 generation fitness: 50.299499999999995
# 14 generation fitness: 50.79691891891891
# 15 generation fitness: 50.79691891891891
# 16 generation fitness: 50.79691891891891
# 17 generation fitness: 50.79691891891891
# 18 generation fitness: 51.32197222222222
# 19 generation fitness: 51.32197222222222
# 20 generation fitness: 51.32197222222222
# 21 generation fitness: 51.32197222222222
# 22 generation fitness: 51.32197222222222
# ...

# %%
# Main single objective GS2 using PSO
PSO_GS2_SO = pso(FGS2,10, "GS2", 50, 0.3, 0.5)
# Out:
# initial population fitness: 41.29914285714285
# 1 generation fitness: 48.41994736842104
# 2 generation fitness: 48.55777272727273
# 3 generation fitness: 48.55777272727273
# 4 generation fitness: 53.17531578947368
# 5 generation fitness: 53.17531578947368
# 6 generation fitness: 54.3701
# 7 generation fitness: 54.3701
# 8 generation fitness: 54.3701
# 9 generation fitness: 54.3701
# 10 generation fitness: 54.3701
# 11 generation fitness: 54.3701
# 12 generation fitness: 54.3701
# 13 generation fitness: 54.3701
# 14 generation fitness: 54.3701
# 15 generation fitness: 54.3701
# 16 generation fitness: 54.3701
# 17 generation fitness: 54.3701
# 18 generation fitness: 54.3701
# 19 generation fitness: 54.3701
# 20 generation fitness: 54.3701
# 21 generation fitness: 54.3701
# 22 generation fitness: 54.3701
# 23 generation fitness: 54.3701
# 24 generation fitness: 54.3701
# 25 generation fitness: 54.3701
# 26 generation fitness: 54.3701
# 27 generation fitness: 54.3701
# ...

# %%
#Plotting the Single objective fitness function for Ground Station 1 using PSO
# using subplot function and creating plot one
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)
plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(PSO_GS1_SO[2], 'b', linewidth=1, linestyle='-')
plt.title('Single Objective of GS1 using PSO')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2)
plt.plot(PSO_GS2_SO[2], 'b', linewidth=1, linestyle='-')
plt.title('Single-Objective of GS2 using PSO')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# space between the plots
plt.tight_layout(4)
 
# show plot
plt.show()
# Out:
# C:\Users\Tanmayee\AppData\Local\Temp/ipykernel_27608/3586813435.py:22: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %%
trs = []
for route in PSO_GS1_SO[1] + PSO_GS2_SO[1]:
    tr = tr_rate(route)
    trs.append(tr)
trs_set = set(trs)
print('Transmission rate')
for v in trs_set:
    print(v, ':',trs.count(v))
# Out:
# Transmission rate
# 43.505 : 1
# 77.071 : 6
# 52.857 : 3
# 119.13 : 6
# 31.895 : 35
# 93.854 : 4
# 63.97 : 1

# %%
Route_PSO1 = GA_GS1_SO[1] + GA_GS2_SO[1]
Route_PSO1
# Out:
# [[63, 'GS1'],
#  [191, 181, 'GS1'],
#  [132, 'GS1'],
#  [136, 93, 159, 74, 'GS1'],
#  [12, 140, 206, 209, 6, 51, 55, 'GS1'],
#  [120, 188, 41, 89, 'GS1'],
#  [109, 24, 'GS1'],
#  [214, 43, 163, 'GS1'],
#  [71, 'GS1'],
#  [59, 'GS1'],
#  [211, 129, 31, 'GS1'],
#  [160, 95, 149, 178, 'GS1'],
#  [158, 144, 78, 'GS1'],
#  [207, 49, 54, 'GS1'],
#  [197, 4, 40, 193, 'GS1'],
#  [58, 176, 'GS1'],
#  [195, 190, 194, 'GS1'],
#  [15, 'GS1'],
#  [203, 52, 32, 19, 92, 48, 133, 164, 200, 28, 153, 154, 185, 189, 'GS1'],
#  [179, 138, 73, 'GS1'],
#  [39, 187, 174, 87, 151, 131, 213, 30, 2, 84, 'GS1'],
#  [68, 182, 79, 81, 104, 205, 3, 'GS1'],
#  [165, 'GS1'],
#  [201, 96, 'GS1'],
#  [212, 107, 139, 'GS1'],
#  [204, 'GS1'],
#  [166, 101, 'GS1'],
#  [152, 'GS1'],
#  [77, 167, 'GS1'],
#  [69, 'GS1'],
#  [47, 'GS1'],
#  [146, 'GS1'],
#  [157, 'GS1'],
#  [122, 'GS1'],
#  [67, 161, 'GS1'],
#  [75, 'GS1'],
#  [35, 100, 'GS1'],
#  [99, 'GS1'],
#  [168, 21, 186, 22, 'GS2'],
#  [145, 'GS2'],
#  [7, 'GS2'],
# ...

# %% [markdown]
# <H3><p style="font-family:Georgia;">Plotting the Routing for the PSO Algorithm for Single Objective</H3>

# %%
plt.figure(figsize=(20,16))

for flight in FGS1:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot1= plt.scatter(x,y,c='c')

for flight in FGS2:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot2= plt.scatter(x,y,c='g')
    
plot3 = plt.scatter(XGS1,YGS1,c='black',marker='v',s=300)
plot4 = plt.scatter(XGS2,YGS2,c='red',marker='^',s=300)

random.shuffle(Route_PSO1) # change the Route for all outputs
plot_route = []
k = 0
for route in Route_PSO1:
    if len(route)> 5:
        plot_route.append(route)
        k+=1
    if k == 6:
        break

k = 0
for route in plot_route:
    color={1:'c',2:'b',3:'m',4:'r',5:'g',6:'y'}
    k+=1
    for i in range(1,len(route)):
        
        x1= df.loc[route[i-1],'X']
        y1= df.loc[route[i-1],'Y']
        
        if route[i] == 'GS1':
            x2 = XGS1
            y2 = YGS1
        elif route[i] == 'GS2':
            x2 = XGS2
            y2 = YGS2
        else:
            x2= df.loc[route[i],'X']
            y2= df.loc[route[i],'Y']
        plt.plot([x1,x2],[y1,y2],color=color[k])
        
        
plt.xlabel('x-cartesian')
plt.ylabel('y-cartesian')
plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
           scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
plt.show(block=True)

# %%
# Main multi objective GS1 using PSO
PSO_GS1_MO = pso2(FGS1,10, "GS1", 50, 0.3, 0.5)
# Out:
# initial population fitness: 96.55345833333332
# 1 generation fitness: 96.55345833333332
# 2 generation fitness: 103.17540909090908
# 3 generation fitness: 103.17540909090908
# 4 generation fitness: 103.17540909090908
# 5 generation fitness: 109.426671875
# 6 generation fitness: 109.426671875
# 7 generation fitness: 110.78971874999999
# 8 generation fitness: 113.24858064516127
# 9 generation fitness: 113.24858064516127
# 10 generation fitness: 113.24858064516127
# 11 generation fitness: 113.24858064516127
# 12 generation fitness: 113.24858064516127
# 13 generation fitness: 113.24858064516127
# 14 generation fitness: 113.24858064516127
# 15 generation fitness: 113.24858064516127
# 16 generation fitness: 113.24858064516127
# 17 generation fitness: 113.24858064516127
# 18 generation fitness: 113.24858064516127
# 19 generation fitness: 113.24858064516127
# 20 generation fitness: 113.24858064516127
# 21 generation fitness: 113.24858064516127
# 22 generation fitness: 113.24858064516127
# ...

# %%
# Main multi objective GS2 using PSO
PSO_GS2_MO = pso2(FGS2,10, "GS2", 50, 0.3,0.5)
# Out:
# initial population fitness: 105.7867
# 1 generation fitness: 105.7867
# 2 generation fitness: 105.7867
# 3 generation fitness: 116.37460714285713
# 4 generation fitness: 125.15424999999999
# 5 generation fitness: 125.15424999999999
# 6 generation fitness: 127.30042307692307
# 7 generation fitness: 130.53083333333333
# 8 generation fitness: 130.53083333333333
# 9 generation fitness: 130.53083333333333
# 10 generation fitness: 130.53083333333333
# 11 generation fitness: 130.53083333333333
# 12 generation fitness: 130.53083333333333
# 13 generation fitness: 130.53083333333333
# 14 generation fitness: 130.53083333333333
# 15 generation fitness: 130.53083333333333
# 16 generation fitness: 130.53083333333333
# 17 generation fitness: 130.53083333333333
# 18 generation fitness: 130.53083333333333
# 19 generation fitness: 130.53083333333333
# 20 generation fitness: 130.53083333333333
# 21 generation fitness: 130.53083333333333
# 22 generation fitness: 130.53083333333333
# ...

# %%
#Plotting the Multi objective functions fitness for Ground Station 1 using PSO
# using subplot function and creating plot one
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)
plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(PSO_GS1_MO[2], 'b', linewidth=1, linestyle='-')
plt.title('Multi Objective of GS1 using PSO')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2)
plt.plot(PSO_GS2_MO[2], 'b', linewidth=1, linestyle='-')
plt.title('Multi-Objective of GS2 using PSO')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# space between the plots
plt.tight_layout(4)
 
# show plot
plt.show()
# Out:
# C:\Users\Tanmayee\AppData\Local\Temp/ipykernel_27608/2175983104.py:22: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %%
trs = []
las = []
for route in PSO_GS1_MO[1] + PSO_GS2_MO[1]:
    tr = tr_rate(route)
    la = 50 * (len(route)-1)
    trs.append(tr)
    las.append(la)
trs_set = set(trs)
print('Transmission rate')
for v in trs_set:
    print(v, ':',trs.count(v))
print('\n Latency')
las_set = set(las)
for v in las_set:
    print(v, ':',las.count(v))
# Out:
# Transmission rate
# 119.13 : 3
# 52.857 : 1
# 31.895 : 39
#
#  Latency
# 450 : 3
# 100 : 9
# 200 : 4
# 300 : 1
# 400 : 2
# 50 : 5
# 150 : 11
# 600 : 1
# 250 : 6
# 350 : 1

# %%
Route_PSO2 = GA_GS1_MO[1] + GA_GS2_MO[1]
Route_PSO2
# Out:
# [[19, 201, 211, 181, 'GS1'],
#  [52, 30, 81, 167, 178, 'GS1'],
#  [63, 'GS1'],
#  [129, 54, 'GS1'],
#  [184, 120, 204, 'GS1'],
#  [2, 139, 'GS1'],
#  [153, 'GS1'],
#  [38, 166, 39, 202, 182, 209, 195, 48, 40, 189, 'GS1'],
#  [36, 165, 'GS1'],
#  [59, 'GS1'],
#  [172, 84, 157, 'GS1'],
#  [213, 104, 176, 151, 206, 47, 'GS1'],
#  [136, 60, 163, 146, 'GS1'],
#  [123, 'GS1'],
#  [214, 58, 'GS1'],
#  [125, 'GS1'],
#  [91, 193, 'GS1'],
#  [190, 207, 31, 27, 205, 0, 112, 159, 169, 140, 1, 'GS1'],
#  [203, 'GS1'],
#  [69, 'GS1'],
#  [33, 97, 'GS1'],
#  [191, 174, 105, 122, 3, 11, 75, 'GS1'],
#  [12, 197, 77, 170, 87, 61, 'GS1'],
#  [164, 6, 152, 'GS1'],
#  [50, 142, 78, 'GS1'],
#  [41, 109, 161, 'GS1'],
#  [160, 57, 132, 89, 'GS1'],
#  [35, 158, 187, 68, 15, 'GS1'],
#  [51, 'GS1'],
#  [99, 'GS1'],
#  [26, 107, 101, 'GS1'],
#  [71, 'GS1'],
#  [133, 177, 93, 74, 'GS1'],
#  [17, 83, 121, 14, 150, 110, 21, 208, 20, 8, 53, 'GS2'],
#  [82, 111, 'GS2'],
#  [98, 'GS2'],
#  [42, 116, 'GS2'],
# ...

# %% [markdown]
# <H3><p style="font-family:Georgia;">Plotting the Routing for the PSO Algorithm for Multiple Objective</H3>

# %%
plt.figure(figsize=(20,16))

for flight in FGS1:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot1= plt.scatter(x,y,c='c')

for flight in FGS2:
    x= df.loc[flight,'X']
    y= df.loc[flight,'Y']
    plot2= plt.scatter(x,y,c='g')
    
plot3 = plt.scatter(XGS1,YGS1,c='black',marker='v',s=300)
plot4 = plt.scatter(XGS2,YGS2,c='red',marker='^',s=300)

random.shuffle(Route_PSO2) # change the Route for all outputs
plot_route = []
k = 0
for route in Route_PSO2:
    if len(route)> 5:
        plot_route.append(route)
        k+=1
    if k == 6:
        break

k = 0
for route in plot_route:
    color={1:'c',2:'b',3:'m',4:'r',5:'g',6:'y'}
    k+=1
    for i in range(1,len(route)):
        
        x1= df.loc[route[i-1],'X']
        y1= df.loc[route[i-1],'Y']
        
        if route[i] == 'GS1':
            x2 = XGS1
            y2 = YGS1
        elif route[i] == 'GS2':
            x2 = XGS2
            y2 = YGS2
        else:
            x2= df.loc[route[i],'X']
            y2= df.loc[route[i],'Y']
        plt.plot([x1,x2],[y1,y2],color=color[k])
        
        
plt.xlabel('x-cartesian')
plt.ylabel('y-cartesian')
plt.legend((plot1, plot2, plot3, plot4),('Flights-LHR','Flights-EWR', 'LHR - Ground Station','EWR - Ground Station'),
           scatterpoints=1,loc='upper right',ncol=1,fontsize=12)
plt.show(block=True)

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;"> Results and Discussion</p></H3>

# %%
#Plotting the single objective functions fitness for Ground Station 1 using Genetic and PSO 
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)
plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(GA_GS1_SO[2],label="Genetic Algorithm", linewidth=1, linestyle='-')
plt.plot(PSO_GS1_SO[2],label="PSO", linewidth=1, linestyle='-')
plt.legend()
plt.title('Comparing Single Objective of GS1')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
#Plotting the single objective functions fitness for Ground Station 2 using Genetic and PSO
plt.subplot(1, 2, 2)
plt.plot(GA_GS2_SO[2],label="Genetic Algorithm", linewidth=1, linestyle='-')
plt.plot(PSO_GS2_SO[2],label="PSO", linewidth=1, linestyle='-')
plt.title('Comparing Single Objective of GS2')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
#Legend
plt.legend()
# space between the plots
plt.tight_layout(4)
 
# show plot
plt.show()
# Out:
# C:\Users\Tanmayee\AppData\Local\Temp/ipykernel_27608/2272076867.py:24: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %%
#Plotting the multi objective functions fitness for Ground Station 1 using Genetic and PSO 
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)
plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(GA_GS1_MO[2],label="Genetic Algorithm", linewidth=1, linestyle='-')
plt.plot(PSO_GS1_MO[2],label="PSO", linewidth=1, linestyle='-')
plt.legend()
plt.title('Comparing Multi Objective of GS1')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
#Plotting the multi objective functions fitness for Ground Station 2 using Genetic and PSO
plt.subplot(1, 2, 2)
plt.plot(GA_GS2_MO[2],label="Genetic Algorithm", linewidth=1, linestyle='-')
plt.plot(PSO_GS2_MO[2],label="PSO", linewidth=1, linestyle='-')
plt.legend()
plt.title('Comparing Multi Objective of GS2')
plt.xlabel('Generation')
plt.ylabel('Best fitness')
 
# space between the plots
plt.tight_layout(4)
 
# show plot
plt.show()
# Out:
# C:\Users\Tanmayee\AppData\Local\Temp/ipykernel_27608/1610052435.py:23: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %%
#Transmission Rate for Single Optimization Greedy Algorithm 
trs = []
for route in GREEDY_GS1_SO + GREEDY_GS2_SO:
    tr = tr_rate(route)
    trs.append(tr)
trs_set = set(trs)
print('Transmission rate for Greedy Algorithm')
for v in trs_set:
    print(v, ':',trs.count(v))
    
#Transmission Rate for Single Optmization Genetic Algorithm 
trs = []
for route in GA_GS1_SO[1] + GA_GS2_SO[1]:
    tr = tr_rate(route)
    trs.append(tr)
trs_set = set(trs)
print('\n Transmission rate for Genetic Algorithm')
for v in trs_set:
    print(v, ':',trs.count(v))
 
#Transmission Rate for Single Optmization Particle Swarm Optimization Algorithm
trs = []
for route in PSO_GS1_SO[1] + PSO_GS2_SO[1]:
    tr = tr_rate(route)
    trs.append(tr)
trs_set = set(trs)
print('\n Transmission rate for Particle Swarm Optimization')
for v in trs_set:
    print(v, ':',trs.count(v))
# Out:
# Transmission rate for Greedy Algorithm
# 93.854 : 2
# 77.071 : 2
# 52.857 : 1
# 31.895 : 25
#
#  Transmission rate for Genetic Algorithm
# 77.071 : 2
# 52.857 : 2
# 119.13 : 6
# 93.854 : 4
# 31.895 : 40
#
#  Transmission rate for Particle Swarm Optimization
# 43.505 : 1
# 77.071 : 6
# 52.857 : 3
# 119.13 : 6
# 31.895 : 35
# 93.854 : 4
# 63.97 : 1

# %% [markdown]
# <H5 style="color:black;"><p style="font-family:Georgia;">Discussion on Results of Single objective optimization for maximum End-to-End Transmission Rate</H5>
# <p style="font-family:Georgia;"> In the context of single objective optimization, these algorithms can be effective at finding high transmission rates because they are able to search through a large space of possible solutions and identify those that are most likely to result in high transmission rates. They do this by evaluating the performance of each solution and then using this information to guide the search process towards better solutions.
# <p style="font-family:Georgia;"> There are several factors that can contribute to the success of these algorithms in finding high transmission rates, including the size and complexity of the problem being solved, the quality of the initial solution, and the specific parameters and settings used for the algorithm. However, overall, genetic algorithms and PSO tend to be effective at finding high transmission rates for single objective optimization problems because of their ability to search through a large space of possible solutions and identify those that are most likely to be successful.
# <p style="font-family:Georgia;">  The problem statement requires finding a routing path with the highest end-to-end data transmission rate for each airplane that can access any of a GS. <B>The Genetic Algorithm and Particle Swarm Optimization both have maximum end-to-end transmission rate</B>. In the Greedy Algorithm the maximum end-to-end transmission rate of 93.854.

# %%
#Transmission Rate for Multi Optmization Greedy Algorithm
trs = []
las = []
for route in GREEDY_GS1_MO + GREEDY_GS2_MO:
    tr = tr_rate(route)
    la = 50 * (len(route)-1)
    trs.append(tr)
    las.append(la)
trs_set = set(trs)
print('Transmission rate for Greedy Algorithm')
for v in trs_set:
    print(v, ':',trs.count(v))
print('\n Latency for Greedy Algorithm')
las_set = set(las)
for v in las_set:
    print(v, ':',las.count(v))

#Transmission Rate for Multi Optmization Genetic Algorithm
trs = []
las = []
for route in GA_GS1_MO[1] + GA_GS2_MO[1]:
    tr = tr_rate(route)
    la = 50 * (len(route)-1)
    trs.append(tr)
    las.append(la)
trs_set = set(trs)
print('\n Transmission rate for Genetic Algorithm')
for v in trs_set:
    print(v, ':',trs.count(v))
print('\n Latency for Genetic Algorithm')
las_set = set(las)
for v in las_set:
    print(v, ':',las.count(v))
    
#Transmission Rate for Multi Optmization PSO Algorithm
trs = []
las = []
for route in PSO_GS1_MO[1] + PSO_GS2_MO[1]:
    tr = tr_rate(route)
    la = 50 * (len(route)-1)
    trs.append(tr)
    las.append(la)
trs_set = set(trs)
print('\nTransmission rate for PSO')
for v in trs_set:
    print(v, ':',trs.count(v))
print('\n Latency for PSO Algorithm')
las_set = set(las)
for v in las_set:
    print(v, ':',las.count(v))
# Out:
# Transmission rate for Greedy Algorithm
# 43.505 : 1
# 77.071 : 6
# 52.857 : 6
# 119.13 : 6
# 31.895 : 165
# 93.854 : 4
# 63.97 : 2
#
#  Latency for Greedy Algorithm
# 50 : 167
# 100 : 22
# 150 : 1
#
#  Transmission rate for Genetic Algorithm
# 119.13 : 4
# 77.071 : 2
# 93.854 : 1
# 31.895 : 40
#
#  Latency for Genetic Algorithm
# 450 : 1
# 100 : 9
# 550 : 2
# 200 : 4
# 300 : 2
# 400 : 1
# 50 : 14
# 500 : 1
# 150 : 8
# 250 : 3
# 350 : 2
#
# Transmission rate for PSO
# 119.13 : 3
# 52.857 : 1
# 31.895 : 39
#
#  Latency for PSO Algorithm
# 450 : 3
# 100 : 9
# 200 : 4
# 300 : 1
# 400 : 2
# 50 : 5
# 150 : 11
# 600 : 1
# 250 : 6
# 350 : 1

# %% [markdown]
# <H5 style="color:black;"><p style="font-family:Georgia;">Discussion on Results of Multi objective optimization for maximum End-to-End Transmission Rate and minimum Latency</H5>
# <p style="font-family:Georgia;">Greedy, Particle Swarm Optimization (PSO) and Genetic Algorithm (GA) are optimization algorithms used for finding the optimal solution for multiple objectives. Greedy algorithm is used to make the best decision at each step in order to maximize or minimize a given objective function. PSO is a population-based stochastic optimization technique used for finding the global optimum solution to a given problem. GA is a search-based optimization technique that uses evolutionary principles of natural selection and genetic operators to obtain the best solution to a given problem.
# <p style="font-family:Georgia;">These algorithms are used in multiple objective optimization because they offer the maximum transmission rate. They are able to find the best solution possible by considering multiple objectives at the same time, thus providing the maximum transmission rate. Furthermore, they can handle multiple objectives that may conflict with each other, and still obtain the best solution. Additionally, they offer better scalability than other optimization techniques, making them suitable for large-scale problems.
# <p style="font-family:Georgia;">Greedy algorithms tend to have minimum latency because they make decisions based on the current state of the system. This means that they can quickly identify the best solution from the available options, without having to consider all possible solutions. This makes them suitable for problems with multiple objectives, as they can quickly identify the best solution for each objective.
# <p style="font-family:Georgia;"> The problem statement requires finding a routing path that has the maximum end-to-end data transmission rate and minimum end-to-end latency for each airplane that can access any of a GS. <B>Among all the routes, we have obtained a maximum end-to-end transmission rate of up to 119 in all the applied algorithms.</B>
# <p style="font-family:Georgia;"> <B>The latency is minimum in the Greedy Algorithm.</B> The worst case latency for the Genetic Algorithm is in the range of 550, while the latency for the PSO is 600.

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Generating JSON File</p></H3>

# %%
import json
def JSONfile(Routes, filename):
    filename = filename + ".json"
    for route in Routes:
        routing_path = {"Source Node": None,
                            "Routing Path": [],
                            "End-to-end data rate": None}
        for i in range(len(route)):
            if i == 0:
                routing_path["Source Node"] = route[i]
                pre_node = route[i]
            else:
                rate = datarate2points(pre_node,route[i])
                routing_path["Routing Path"].append((route[i],rate))
                pre_node = route[i]
        routing_path["End-to-end data rate"] = tr_rate(route)
                
        # Serializing json
        json_object = json.dumps(routing_path, indent=2)
        # Writing to Routing_paths.json
        with open(filename, "a") as outfile:
            outfile.write(json_object)
            outfile.write('\n')

# %%
JSONfile(Route_PSO1, "Single_Solution") # change the route

# %%
JSONfile(Route_PSO2, "Multi_Solution")

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;"> Challenges Faced and Overcomed</p></H3>
# <ul style="font-family:Georgia;"><li>One of the challenges in completing the assignment was accurately determining the locations of the flights and the ground stations, as outlined in the assignment brief. This was overcome by properly converting the latitude, longitude, and altitude values, and by taking into account the negative values of longitude for both ground stations.</li>
# <li>Initially, it was difficult to determine which routing algorithm could be implemented for the given problem. However, after conducting some research and taking the time to explore potential solutions, the appropriate solution was eventually identified.</li>
# <li>A key aspect of using a genetic algorithm to solve the problem was selecting the appropriate selection, mutation, and crossover methods in order to effectively find a solution.</li>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;"> Conclusion</H3>
# <p style="font-family:Georgia;">After observing the fitness function, it can be seen that PSO is giving better results. Both PSO and the Genetic Algorithm have higher transmission rates. The Greedy Algorithm has the lowest latency rate. The Genetic Algorithm took more time to execute compared to PSO, but the Greedy Algorithm is obviously faster because it has no loops.

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">Future Scope</H3>
# <p style="font-family:Georgia;"> There are several ways you could extend the current implementation to improve the performance of the algorithms. Some possibilities include:
# <ol style="font-family:Georgia;"><li><B>Combining GS1 and GS2:</B> One potential approach would be to combine GS1 and GS2 into a single list and then apply the optimization algorithms to this combined list. This could potentially improve the quality of the routes generated by the algorithms, as it would allow them to consider more possible flight combinations.</li>
#
# <li><B>Implementing more optimization algorithms:</B> Another option would be to implement additional optimization algorithms, such as simulated annealing or tabu search, and compare their results to the existing algorithms. This could help identify which algorithm performs the best in terms of generating high-quality routes.</li>
#
# <li><B>Selecting different methods of selection and cross-over for the genetic algorithm:</B> Another way to improve the performance of the genetic algorithm would be to experiment with different methods of scramble, selection, and cross-over. For example, you could try using different selection methods, such as tournament selection or rank-based selection, or experiment with different cross-over techniques, such as one-point or two-point cross-over.</li>
#
# <li><B>Analyzing the impact of different parameter settings:</B> Finally, you could explore how different parameter settings impact the performance of the algorithms. For example, you could study the effect of different population sizes or number of generations on the quality of the routes generated by the algorithms.</li></ol>
#
# <p style="font-family:Georgia;">Overall, there are many ways to extend the current implementation to improve the performance of the algorithms and generate more efficient routes. By experimenting with different approaches and analyzing the results, we can identify which methods are most effective and refine implementation accordingly.</p>

# %% [markdown]
# <H3 style="color:teal;"><p style="font-family:Georgia;">References</H3>
# <ol style="font-family:Georgia;"><li>Zhang, J., Xiang, L., Liu, D., Cui, J., Ng, S. X., Maunder, R. G., Graeupl, T., Carsten-Fiebig, U. and Hanzo, L., 2021. Semi-stochastic aircraft mobility modelling for aeronautical networks: An Australian case-study based on real flight data. IEEE transactions on vehicular technology [online], 70 (10), 10763–10779. Available from: https://eprints.soton.ac.uk/450888/ [Accessed 27 Dec 2022].</li>
# <li> Saleh, S. A., Ahmed, S. K. and Nashat, F. S., 2020. A genetic algorithm for solving an optimization problem: Decision making in project management. In: 2020 International Conference on Computer Science and Software Engineering (CSASE). IEEE.</li>
# <li>Sahay, K. B., Kumar, N. and Tripathi, M. M., 2014. Implementation of different optimization techniques to solve ELD problem. In: 2014 6th IEEE Power India International Conference (PIICON). IEEE, 1–6.</li>
# <li>Zhang, J., Liu, D., Chen, S., Ng, S. X., Maunder, R. G. and Hanzo, L., 2022. Multiple-objective packet routing optimization for aeronautical ad-hoc networks. arXiv [cs.IT] [online]. Available from: http://arxiv.org/abs/2208.12567.</li>
# <li>Cui, J., Ng, S. X., Liu, D., Zhang, J., Nallanathan, A. and Hanzo, L., 2021. Multiobjective optimization for integrated ground-air-space networks: Current research and future challenges. IEEE vehicular technology magazine [online], 16 (3), 88–98. Available from: http://dx.doi.org/10.1109/mvt.2021.3085511.</li>
# <li>Li, C., Zhao, X. and Li, Y., 2015. Research on vehicle routing optimization in an emergency based on intersection delay. In: CICTP 2015. Reston, VA: American Society of Civil Engineers.</li>
# <li>Kennedy, J. and Eberhart, R., 2002. Particle swarm optimization. In: Proceedings of ICNN’95 - International Conference on Neural Networks. IEEE.</li>
# <li>Kirkpatrick, S., Gelatt, C. D., Jr and Vecchi, M. P., 1983. Optimization by simulated annealing. Science (New York, N.Y.) [online], 220 (4598), 671–680. Available from: http://dx.doi.org/10.1126/science.220.4598.671.</li>
# <li>Chong, E. K. P. and Zak, S. H., 2014. An Introduction to Optimization. 4th ed. Nashville, TN, USA: John Wiley & Sons.</li>
# <li>Goldberg, D. E., 2013. The design of innovation: Lessons from and for competent genetic algorithms. New York, NY, USA: Springer.</li></
# <li>Anon., 2023. Pandas Guide — Pandas Guide documentation [online]. Readthedocs.io. Available from: https://pandasguide.readthedocs.io/en/latest/</li>
# <li>Anon., 2023b. Basemap tutorial — Basemap tutorial 0.1 documentation [online]. Readthedocs.io. Available from: https://basemaptutorial.readthedocs.io/en/latest/ </li></ol>
